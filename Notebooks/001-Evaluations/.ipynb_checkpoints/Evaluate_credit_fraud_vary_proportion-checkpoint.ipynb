# %%
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import logging
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from collections import Counter
from Evaluation import synthsonic, writetodict, plotter, plot_oversampling, evaluate_oversamplers
import smote_variants as sv
from sklearn.tree import DecisionTreeClassifier

# %%
# metrics 

from imblearn.metrics import geometric_mean_score, classification_report_imbalanced

from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import (recall_score, roc_auc_score, confusion_matrix, 
                             f1_score, brier_score_loss, balanced_accuracy_score, accuracy_score)

# %%
le = preprocessing.LabelEncoder()
random_state=4

_logger = logging.getLogger('smote_variants')
_logger.setLevel(logging.DEBUG)
_logger_ch = logging.StreamHandler()
_logger_ch.setFormatter(logging.Formatter(
    "%(asctime)s:%(levelname)s:%(message)s"))
_logger.addHandler(_logger_ch)

# %%
# loading datasets

path = "/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/Datasets/"
data = path+"credit_fraud.csv"

data = pd.read_csv(data)

plotter(data.iloc[:,:-1].values,data.iloc[:,-1].values, "distribution")

data_dict = writetodict(data, 'credit_fraud')
X,y,name = data_dict['data'],data_dict['target'],data_dict['name']
# Out:
# Counter({0: 284315, 1: 492})

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = random_state)

# %% [markdown]
# # analysis of plots

# %%
proportions = [0.1,0.3,0.5,0.7,0.9,1]

# %%
samples = []

for prop in proportions :
    o = synthsonic(proportion = prop,
                   random_state = random_state)
    
    print(prop)
    x_g, y_g = o.sample(X_train,y_train)
    
    f_dict = {
        'prop':prop,
        'x_sample':x_g,
        'y_sample':y_g
    }
    
    samples.append(f_dict)
# Out:
# 2021-06-07 11:37:36,527:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.1, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE74B3F09E0}")
# 2021-06-07 11:37:36,527:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.1, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE74B3F09E0}")
# 2021-06-07 11:37:36,527:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.1, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE74B3F09E0}")
# n_quantiles (500) is greater than the total number of samples (345). n_quantiles is set to num samples.
# 0.1
# minority class 1, min dataset (345, 29)
#   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:  29%|██▊       | 108/378.0 [00:00<00:00, 1033.34it/s]
# Building tree:  54%|█████▍    | 204/378.0 [00:00<00:00, 988.77it/s]
# Building tree: 100%|██████████| 378/378.0 [00:00<00:00, 936.88it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:09,  2.94it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:09,  2.94it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:07,  3.51it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:07,  3.51it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:07,  3.50it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:07,  3.50it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:01<00:07,  3.52it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:01<00:07,  3.52it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:01<00:06,  3.51it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:01<00:06,  3.51it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:06,  3.50it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:06,  3.50it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:06,  3.42it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:06,  3.42it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:02<00:06,  3.40it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:02<00:06,  3.40it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:02<00:05,  3.42it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:02<00:05,  3.42it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:02<00:05,  3.24it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:02<00:05,  3.24it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:03<00:05,  3.26it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:03<00:05,  3.26it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:03<00:05,  3.25it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:03<00:05,  3.25it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:03<00:04,  3.22it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:03<00:04,  3.22it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:04<00:04,  3.15it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:04<00:04,  3.15it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:04<00:04,  3.11it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:04<00:04,  3.11it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:04<00:04,  3.13it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:04<00:04,  3.13it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:05<00:03,  3.25it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:05<00:03,  3.25it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:05<00:03,  3.35it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:05<00:03,  3.35it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:05<00:02,  3.42it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:05<00:02,  3.42it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:05<00:02,  3.40it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:05<00:02,  3.40it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:06<00:02,  3.45it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:06<00:02,  3.45it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:06<00:02,  3.43it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:06<00:02,  3.43it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:06<00:01,  3.51it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:06<00:01,  3.51it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:07<00:01,  3.57it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:07<00:01,  3.57it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:07<00:01,  3.70it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:07<00:01,  3.70it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:07<00:00,  3.77it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:07<00:00,  3.77it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:07<00:00,  3.80it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:07<00:00,  3.80it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:08<00:00,  3.23it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:08<00:00,  3.23it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:08<00:00,  3.41it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 26:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:01, 20.63it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:01, 20.63it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:00<00:01, 15.40it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:00<00:01, 15.40it/s]
# Generating for node: 13:  14%|█▍        | 4/29 [00:00<00:01, 15.40it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:00<00:01, 13.99it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:00<00:01, 13.99it/s]
# Generating for node: 3:  21%|██        | 6/29 [00:00<00:01, 13.99it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:00<00:01, 12.79it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:00<00:01, 12.79it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:00<00:01, 11.10it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:00<00:01, 11.10it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:00<00:01, 10.46it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:00<00:01, 10.46it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:00<00:01,  9.44it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:00<00:01,  9.44it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:01<00:01,  9.00it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:01<00:01,  9.00it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:01<00:01,  8.77it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:01<00:01,  8.77it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:01<00:01,  8.52it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:01<00:01,  8.52it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:01<00:01,  8.43it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:01<00:01,  8.43it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:01<00:01,  8.58it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:01<00:01,  8.58it/s]
# Generating for node: 15:  55%|█████▌    | 16/29 [00:01<00:01,  8.58it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:01<00:01,  9.03it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:01<00:01,  9.03it/s]
# Generating for node: 12:  62%|██████▏   | 18/29 [00:01<00:01,  9.03it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:01<00:00,  9.44it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:01<00:00,  9.44it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:02<00:00,  9.39it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:02<00:00,  9.39it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:02<00:00,  9.54it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:02<00:00,  9.54it/s]
# Generating for node: 23:  76%|███████▌  | 22/29 [00:02<00:00,  9.54it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:02<00:00,  9.75it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:02<00:00,  9.75it/s]
# Generating for node: 14:  83%|████████▎ | 24/29 [00:02<00:00,  9.75it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:02<00:00, 10.10it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:02<00:00, 10.10it/s]
# Generating for node: 24:  90%|████████▉ | 26/29 [00:02<00:00, 10.10it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:02<00:00, 10.55it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:02<00:00, 10.38it/s]
# 2021-06-07 11:37:59,150:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.3, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE73110D8D0}")
# 2021-06-07 11:37:59,150:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.3, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE73110D8D0}")
# 2021-06-07 11:37:59,150:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.3, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE73110D8D0}")
# n_quantiles (500) is greater than the total number of samples (345). n_quantiles is set to num samples.
# 0.3
# minority class 1, min dataset (345, 29)
#   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:  29%|██▊       | 108/378.0 [00:00<00:00, 1055.66it/s]
# Building tree:  57%|█████▋    | 216/378.0 [00:00<00:00, 1026.52it/s]
# Building tree: 100%|██████████| 378/378.0 [00:00<00:00, 998.17it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:09,  2.92it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:09,  2.92it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:07,  3.41it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:07,  3.41it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:08,  3.25it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:08,  3.25it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:01<00:08,  3.10it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:01<00:08,  3.10it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:01<00:08,  2.95it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:01<00:08,  2.95it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:07,  3.01it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:07,  3.01it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:02<00:06,  3.15it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:02<00:06,  3.15it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:02<00:06,  3.25it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:02<00:06,  3.25it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:02<00:06,  3.28it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:02<00:06,  3.28it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:03<00:05,  3.34it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:03<00:05,  3.34it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:03<00:05,  3.42it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:03<00:05,  3.42it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:03<00:04,  3.52it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:03<00:04,  3.52it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:03<00:04,  3.65it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:03<00:04,  3.65it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:04<00:04,  3.74it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:04<00:04,  3.74it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:04<00:03,  3.78it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:04<00:03,  3.78it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:04<00:03,  3.78it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:04<00:03,  3.78it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:04<00:03,  3.82it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:04<00:03,  3.82it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:05<00:02,  3.86it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:05<00:02,  3.86it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:05<00:02,  3.91it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:05<00:02,  3.91it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:05<00:02,  3.90it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:05<00:02,  3.90it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:05<00:02,  3.87it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:05<00:02,  3.87it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:06<00:01,  3.92it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:06<00:01,  3.92it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:06<00:01,  3.96it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:06<00:01,  3.96it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:06<00:01,  3.87it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:06<00:01,  3.87it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:06<00:01,  3.95it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:06<00:01,  3.95it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:07<00:00,  3.97it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:07<00:00,  3.97it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:07<00:00,  3.81it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:07<00:00,  3.81it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:07<00:00,  3.68it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:07<00:00,  3.68it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:08<00:00,  3.61it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 26:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:02, 12.64it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:02, 12.64it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:00<00:02, 10.78it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:00<00:02, 10.78it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:00<00:02,  9.88it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:00<00:02,  9.88it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:00<00:02,  9.38it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:00<00:02,  9.38it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:00<00:02,  9.07it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:00<00:02,  9.07it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:00<00:02,  8.44it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:00<00:02,  8.44it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:00<00:02,  8.22it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:00<00:02,  8.22it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:01<00:02,  8.30it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:01<00:02,  8.30it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:01<00:02,  8.32it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:01<00:02,  8.32it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:01<00:02,  7.87it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:01<00:02,  7.87it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:01<00:02,  7.79it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:01<00:02,  7.79it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:01<00:01,  8.11it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:01<00:01,  8.11it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:01<00:01,  8.19it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:01<00:01,  8.19it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:01<00:01,  8.12it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:01<00:01,  8.12it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:02<00:01,  7.72it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:02<00:01,  7.72it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:02<00:01,  7.58it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:02<00:01,  7.58it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:02<00:01,  7.60it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:02<00:01,  7.60it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:02<00:01,  7.72it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:02<00:01,  7.72it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:02<00:01,  7.73it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:02<00:01,  7.73it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:02<00:00,  7.57it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:02<00:00,  7.57it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:02<00:00,  7.67it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:02<00:00,  7.67it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:02<00:00,  7.95it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:02<00:00,  7.95it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:03<00:00,  8.17it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:03<00:00,  8.17it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:03<00:00,  8.31it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:03<00:00,  8.31it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:03<00:00,  8.50it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:03<00:00,  8.50it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:03<00:00,  8.67it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:03<00:00,  8.67it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:03<00:00,  8.37it/s]
# 2021-06-07 11:38:22,285:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.5, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE6DC49ED10}")
# 2021-06-07 11:38:22,285:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.5, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE6DC49ED10}")
# 2021-06-07 11:38:22,285:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.5, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE6DC49ED10}")
# n_quantiles (500) is greater than the total number of samples (345). n_quantiles is set to num samples.
# 0.5
# minority class 1, min dataset (345, 29)
#   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:  29%|██▊       | 108/378.0 [00:00<00:00, 1066.82it/s]
# Building tree:  57%|█████▋    | 216/378.0 [00:00<00:00, 1030.36it/s]
# Building tree: 100%|██████████| 378/378.0 [00:00<00:00, 995.17it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:09,  2.85it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:09,  2.85it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:07,  3.42it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:07,  3.42it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:07,  3.42it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:07,  3.42it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:01<00:07,  3.43it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:01<00:07,  3.43it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:01<00:06,  3.47it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:01<00:06,  3.47it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:06,  3.47it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:06,  3.47it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:06,  3.50it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:06,  3.50it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:02<00:05,  3.52it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:02<00:05,  3.52it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:02<00:05,  3.56it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:02<00:05,  3.56it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:02<00:05,  3.59it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:02<00:05,  3.59it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:03<00:05,  3.59it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:03<00:05,  3.59it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:03<00:04,  3.62it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:03<00:04,  3.62it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:03<00:04,  3.72it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:03<00:04,  3.72it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:03<00:03,  3.80it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:03<00:03,  3.80it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:04<00:03,  3.76it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:04<00:03,  3.76it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:04<00:03,  3.78it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:04<00:03,  3.78it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:04<00:03,  3.81it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:04<00:03,  3.81it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:04<00:02,  3.84it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:04<00:02,  3.84it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:05<00:02,  3.80it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:05<00:02,  3.80it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:05<00:02,  3.85it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:05<00:02,  3.85it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:05<00:02,  3.87it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:05<00:02,  3.87it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:05<00:01,  3.91it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:05<00:01,  3.91it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:06<00:01,  3.93it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:06<00:01,  3.93it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:06<00:01,  3.97it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:06<00:01,  3.97it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:06<00:00,  4.00it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:06<00:00,  4.00it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:06<00:00,  4.01it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:06<00:00,  4.01it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:07<00:00,  4.04it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:07<00:00,  4.04it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:07<00:00,  4.03it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:07<00:00,  4.03it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:07<00:00,  3.81it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:02, 12.45it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:02, 12.45it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:02,  9.74it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:02,  9.74it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:00<00:02,  8.72it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:00<00:02,  8.72it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:00<00:02,  8.13it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:00<00:02,  8.13it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:00<00:02,  7.76it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:00<00:02,  7.76it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:00<00:02,  7.45it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:00<00:02,  7.45it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:01<00:02,  7.25it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:01<00:02,  7.25it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:01<00:02,  6.94it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:01<00:02,  6.94it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:01<00:02,  6.91it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:01<00:02,  6.91it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:01<00:02,  6.93it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:01<00:02,  6.93it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:01<00:02,  7.03it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:01<00:02,  7.03it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:01<00:02,  7.09it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:01<00:02,  7.09it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:01<00:02,  7.12it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:01<00:02,  7.12it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:02<00:01,  7.14it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:02<00:01,  7.14it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:02<00:01,  7.13it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:02<00:01,  7.13it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:02<00:01,  7.13it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:02<00:01,  7.13it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:02<00:01,  7.10it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:02<00:01,  7.10it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:02<00:01,  7.10it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:02<00:01,  7.10it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:02<00:01,  7.17it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:02<00:01,  7.17it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:02<00:01,  7.19it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:02<00:01,  7.19it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:03<00:00,  7.23it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:03<00:00,  7.23it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:03<00:00,  7.29it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:03<00:00,  7.29it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:03<00:00,  7.28it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:03<00:00,  7.28it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:03<00:00,  7.30it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:03<00:00,  7.30it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:03<00:00,  7.38it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:03<00:00,  7.38it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:03<00:00,  7.44it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:03<00:00,  7.44it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:03<00:00,  7.48it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:03<00:00,  7.48it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:03<00:00,  7.33it/s]
# 2021-06-07 11:38:45,549:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.7, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE74B3F09E0}")
# 2021-06-07 11:38:45,549:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.7, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE74B3F09E0}")
# 2021-06-07 11:38:45,549:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.7, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE74B3F09E0}")
# n_quantiles (500) is greater than the total number of samples (345). n_quantiles is set to num samples.
# 0.7
# minority class 1, min dataset (345, 29)
#   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:  29%|██▊       | 108/378.0 [00:00<00:00, 1062.65it/s]
# Building tree:  57%|█████▋    | 216/378.0 [00:00<00:00, 1036.01it/s]
# Building tree: 100%|██████████| 378/378.0 [00:00<00:00, 1001.88it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:11,  2.55it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:11,  2.55it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:08,  3.10it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:08,  3.10it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:08,  3.19it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:08,  3.19it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:01<00:07,  3.28it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:01<00:07,  3.28it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:01<00:07,  3.38it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:01<00:07,  3.38it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:06,  3.43it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:06,  3.43it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:06,  3.49it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:06,  3.49it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:02<00:05,  3.52it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:02<00:05,  3.52it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:02<00:05,  3.57it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:02<00:05,  3.57it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:02<00:05,  3.61it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:02<00:05,  3.61it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:03<00:04,  3.65it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:03<00:04,  3.65it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:03<00:04,  3.66it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:03<00:04,  3.66it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:03<00:04,  3.75it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:03<00:04,  3.75it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:03<00:03,  3.82it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:03<00:03,  3.82it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:04<00:03,  3.83it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:04<00:03,  3.83it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:04<00:03,  3.83it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:04<00:03,  3.83it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:04<00:03,  3.86it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:04<00:03,  3.86it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:04<00:02,  3.88it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:04<00:02,  3.88it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:05<00:02,  3.89it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:05<00:02,  3.89it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:05<00:02,  3.89it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:05<00:02,  3.89it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:05<00:02,  3.90it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:05<00:02,  3.90it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:05<00:01,  3.92it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:05<00:01,  3.92it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:06<00:01,  3.95it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:06<00:01,  3.95it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:06<00:01,  3.98it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:06<00:01,  3.98it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:06<00:01,  3.99it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:06<00:01,  3.99it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:06<00:00,  4.00it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:06<00:00,  4.00it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:07<00:00,  4.03it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:07<00:00,  4.03it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:07<00:00,  4.05it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:07<00:00,  4.05it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:07<00:00,  3.82it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:03,  7.06it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:03,  7.06it/s]
# Generating for node: 26:   3%|▎         | 1/29 [00:00<00:03,  7.06it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:03,  7.16it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:03,  7.16it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:00<00:03,  6.70it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:00<00:03,  6.70it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:00<00:03,  6.43it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:00<00:03,  6.43it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:00<00:03,  6.25it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:00<00:03,  6.25it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:03,  6.15it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:03,  6.15it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:01<00:03,  6.08it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:01<00:03,  6.08it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:01<00:03,  6.02it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:01<00:03,  6.02it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:01<00:03,  6.00it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:01<00:03,  6.00it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:01<00:02,  6.03it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:01<00:02,  6.03it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:01<00:02,  5.95it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:01<00:02,  5.95it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:02<00:02,  6.00it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:02<00:02,  6.00it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:02<00:02,  6.00it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:02<00:02,  6.00it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:02<00:02,  5.92it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:02<00:02,  5.92it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:02<00:02,  5.88it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:02<00:02,  5.88it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:02<00:02,  5.94it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:02<00:02,  5.94it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:02<00:01,  5.98it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:02<00:01,  5.98it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:03<00:01,  5.97it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:03<00:01,  5.97it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:03<00:01,  6.01it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:03<00:01,  6.01it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:03<00:01,  6.03it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:03<00:01,  6.03it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:03<00:01,  6.00it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:03<00:01,  6.00it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:03<00:00,  6.04it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:03<00:00,  6.04it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:03<00:00,  6.07it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:03<00:00,  6.07it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:04<00:00,  6.11it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:04<00:00,  6.11it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:04<00:00,  6.15it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:04<00:00,  6.15it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:04<00:00,  6.13it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:04<00:00,  6.13it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:04<00:00,  6.20it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:04<00:00,  6.20it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:04<00:00,  6.11it/s]
# 2021-06-07 11:39:10,036:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.9, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE78CDE37C0}")
# 2021-06-07 11:39:10,036:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.9, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE78CDE37C0}")
# 2021-06-07 11:39:10,036:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.9, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE78CDE37C0}")
# n_quantiles (500) is greater than the total number of samples (345). n_quantiles is set to num samples.
# 0.9
# minority class 1, min dataset (345, 29)
#   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:  29%|██▊       | 108/378.0 [00:00<00:00, 1064.96it/s]
# Building tree:  54%|█████▍    | 204/378.0 [00:00<00:00, 1016.18it/s]
# Building tree: 100%|██████████| 378/378.0 [00:00<00:00, 971.62it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:10,  2.58it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:10,  2.58it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:08,  3.14it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:08,  3.14it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:08,  3.23it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:08,  3.23it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:01<00:07,  3.28it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:01<00:07,  3.28it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:01<00:07,  3.34it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:01<00:07,  3.34it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:06,  3.40it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:06,  3.40it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:06,  3.47it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:06,  3.47it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:02<00:06,  3.48it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:02<00:06,  3.48it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:02<00:05,  3.54it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:02<00:05,  3.54it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:02<00:05,  3.56it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:02<00:05,  3.56it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:03<00:05,  3.59it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:03<00:05,  3.59it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:03<00:04,  3.61it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:03<00:04,  3.61it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:03<00:04,  3.70it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:03<00:04,  3.70it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:03<00:03,  3.78it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:03<00:03,  3.78it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:04<00:03,  3.78it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:04<00:03,  3.78it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:04<00:03,  3.79it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:04<00:03,  3.79it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:04<00:03,  3.83it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:04<00:03,  3.83it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:04<00:02,  3.84it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:04<00:02,  3.84it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:05<00:02,  3.86it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:05<00:02,  3.86it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:05<00:02,  3.87it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:05<00:02,  3.87it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:05<00:02,  3.89it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:05<00:02,  3.89it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:05<00:01,  3.90it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:05<00:01,  3.90it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:06<00:01,  3.92it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:06<00:01,  3.92it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:06<00:01,  3.91it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:06<00:01,  3.91it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:06<00:01,  3.96it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:06<00:01,  3.96it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:06<00:00,  3.99it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:06<00:00,  3.99it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:07<00:00,  4.00it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:07<00:00,  4.00it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:07<00:00,  4.03it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:07<00:00,  4.03it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:07<00:00,  3.79it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:05,  5.39it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:05,  5.39it/s]
# Generating for node: 26:   3%|▎         | 1/29 [00:00<00:05,  5.39it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:04,  5.64it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:04,  5.64it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:00<00:04,  5.43it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:00<00:04,  5.43it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:00<00:04,  5.27it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:00<00:04,  5.27it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:04,  5.17it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:04,  5.17it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:04,  5.09it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:04,  5.09it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:01<00:04,  5.07it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:01<00:04,  5.07it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:01<00:03,  5.09it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:01<00:03,  5.09it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:01<00:03,  5.05it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:01<00:03,  5.05it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:02<00:03,  5.08it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:02<00:03,  5.08it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:02<00:03,  5.11it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:02<00:03,  5.11it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:02<00:03,  5.10it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:02<00:03,  5.10it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:02<00:02,  5.08it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:02<00:02,  5.08it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:02<00:02,  5.12it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:02<00:02,  5.12it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:03<00:02,  5.11it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:03<00:02,  5.11it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:03<00:02,  5.10it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:03<00:02,  5.10it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:03<00:02,  5.15it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:03<00:02,  5.15it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:03<00:01,  5.12it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:03<00:01,  5.12it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:03<00:01,  5.16it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:03<00:01,  5.16it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:04<00:01,  5.20it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:04<00:01,  5.20it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:04<00:01,  5.23it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:04<00:01,  5.23it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:04<00:01,  5.26it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:04<00:01,  5.26it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:04<00:00,  5.21it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:04<00:00,  5.21it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:04<00:00,  5.20it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:04<00:00,  5.20it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:04<00:00,  5.26it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:04<00:00,  5.26it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:05<00:00,  5.30it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:05<00:00,  5.30it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:05<00:00,  5.28it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:05<00:00,  5.28it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:05<00:00,  5.23it/s]
# 2021-06-07 11:39:36,101:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE6DC49ED10}")
# 2021-06-07 11:39:36,101:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE6DC49ED10}")
# 2021-06-07 11:39:36,101:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'n_jobs': 1, 'distinct_threshold': -1, 'random_state': RandomState(MT19937) at 0x7FE6DC49ED10}")
# n_quantiles (500) is greater than the total number of samples (345). n_quantiles is set to num samples.
# 1
# minority class 1, min dataset (345, 29)
#   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:   0%|          | 0/378.0 [00:00<?, ?it/s]
# Building tree:  29%|██▊       | 108/378.0 [00:00<00:00, 1053.86it/s]
# Building tree:  57%|█████▋    | 216/378.0 [00:00<00:00, 1026.87it/s]
# Building tree: 100%|██████████| 378/378.0 [00:00<00:00, 981.07it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:10,  2.79it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:10,  2.79it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:08,  3.36it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:08,  3.36it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:07,  3.39it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:07,  3.39it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:01<00:07,  3.41it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:01<00:07,  3.41it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:01<00:06,  3.46it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:01<00:06,  3.46it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:06,  3.50it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:06,  3.50it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:06,  3.52it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:06,  3.52it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:02<00:05,  3.56it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:02<00:05,  3.56it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:02<00:05,  3.61it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:02<00:05,  3.61it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:02<00:05,  3.63it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:02<00:05,  3.63it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:03<00:04,  3.65it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:03<00:04,  3.65it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:03<00:04,  3.69it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:03<00:04,  3.69it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:03<00:04,  3.75it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:03<00:04,  3.75it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:03<00:03,  3.82it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:03<00:03,  3.82it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:04<00:03,  3.82it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:04<00:03,  3.82it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:04<00:03,  3.83it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:04<00:03,  3.83it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:04<00:03,  3.81it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:04<00:03,  3.81it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:04<00:02,  3.81it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:04<00:02,  3.81it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:05<00:02,  3.84it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:05<00:02,  3.84it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:05<00:02,  3.73it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:05<00:02,  3.73it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:05<00:02,  3.78it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:05<00:02,  3.78it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:05<00:01,  3.83it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:05<00:01,  3.83it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:06<00:01,  3.88it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:06<00:01,  3.88it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:06<00:01,  3.90it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:06<00:01,  3.90it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:06<00:01,  3.94it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:06<00:01,  3.94it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:06<00:00,  3.97it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:06<00:00,  3.97it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:07<00:00,  3.99it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:07<00:00,  3.99it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:07<00:00,  4.02it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:07<00:00,  4.02it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:07<00:00,  3.81it/s]
#
#   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/29 [00:00<?, ?it/s]
# Generating for node: 1:   3%|▎         | 1/29 [00:00<00:06,  4.59it/s]
# Generating for node: 0:   3%|▎         | 1/29 [00:00<00:06,  4.59it/s]
# Generating for node: 0:   7%|▋         | 2/29 [00:00<00:05,  5.30it/s]
# Generating for node: 26:   7%|▋         | 2/29 [00:00<00:05,  5.30it/s]
# Generating for node: 26:  10%|█         | 3/29 [00:00<00:05,  4.96it/s]
# Generating for node: 6:  10%|█         | 3/29 [00:00<00:05,  4.96it/s]
# Generating for node: 6:  14%|█▍        | 4/29 [00:00<00:05,  4.86it/s]
# Generating for node: 2:  14%|█▍        | 4/29 [00:00<00:05,  4.86it/s]
# Generating for node: 2:  17%|█▋        | 5/29 [00:01<00:05,  4.78it/s]
# Generating for node: 13:  17%|█▋        | 5/29 [00:01<00:05,  4.78it/s]
# Generating for node: 13:  21%|██        | 6/29 [00:01<00:04,  4.77it/s]
# Generating for node: 19:  21%|██        | 6/29 [00:01<00:04,  4.77it/s]
# Generating for node: 19:  24%|██▍       | 7/29 [00:01<00:04,  4.72it/s]
# Generating for node: 3:  24%|██▍       | 7/29 [00:01<00:04,  4.72it/s]
# Generating for node: 3:  28%|██▊       | 8/29 [00:01<00:04,  4.69it/s]
# Generating for node: 11:  28%|██▊       | 8/29 [00:01<00:04,  4.69it/s]
# Generating for node: 11:  31%|███       | 9/29 [00:01<00:04,  4.71it/s]
# Generating for node: 20:  31%|███       | 9/29 [00:01<00:04,  4.71it/s]
# Generating for node: 20:  34%|███▍      | 10/29 [00:02<00:04,  4.71it/s]
# Generating for node: 9:  34%|███▍      | 10/29 [00:02<00:04,  4.71it/s]
# Generating for node: 9:  38%|███▊      | 11/29 [00:02<00:03,  4.71it/s]
# Generating for node: 7:  38%|███▊      | 11/29 [00:02<00:03,  4.71it/s]
# Generating for node: 7:  41%|████▏     | 12/29 [00:02<00:03,  4.70it/s]
# Generating for node: 10:  41%|████▏     | 12/29 [00:02<00:03,  4.70it/s]
# Generating for node: 10:  45%|████▍     | 13/29 [00:02<00:03,  4.72it/s]
# Generating for node: 28:  45%|████▍     | 13/29 [00:02<00:03,  4.72it/s]
# Generating for node: 28:  48%|████▊     | 14/29 [00:02<00:03,  4.75it/s]
# Generating for node: 25:  48%|████▊     | 14/29 [00:02<00:03,  4.75it/s]
# Generating for node: 25:  52%|█████▏    | 15/29 [00:03<00:02,  4.77it/s]
# Generating for node: 16:  52%|█████▏    | 15/29 [00:03<00:02,  4.77it/s]
# Generating for node: 16:  55%|█████▌    | 16/29 [00:03<00:02,  4.75it/s]
# Generating for node: 27:  55%|█████▌    | 16/29 [00:03<00:02,  4.75it/s]
# Generating for node: 27:  59%|█████▊    | 17/29 [00:03<00:02,  4.77it/s]
# Generating for node: 15:  59%|█████▊    | 17/29 [00:03<00:02,  4.77it/s]
# Generating for node: 15:  62%|██████▏   | 18/29 [00:03<00:02,  4.78it/s]
# Generating for node: 8:  62%|██████▏   | 18/29 [00:03<00:02,  4.78it/s]
# Generating for node: 8:  66%|██████▌   | 19/29 [00:03<00:02,  4.76it/s]
# Generating for node: 12:  66%|██████▌   | 19/29 [00:03<00:02,  4.76it/s]
# Generating for node: 12:  69%|██████▉   | 20/29 [00:04<00:01,  4.81it/s]
# Generating for node: 4:  69%|██████▉   | 20/29 [00:04<00:01,  4.81it/s]
# Generating for node: 4:  72%|███████▏  | 21/29 [00:04<00:01,  4.80it/s]
# Generating for node: 5:  72%|███████▏  | 21/29 [00:04<00:01,  4.80it/s]
# Generating for node: 5:  76%|███████▌  | 22/29 [00:04<00:01,  4.85it/s]
# Generating for node: 22:  76%|███████▌  | 22/29 [00:04<00:01,  4.85it/s]
# Generating for node: 22:  79%|███████▉  | 23/29 [00:04<00:01,  4.88it/s]
# Generating for node: 23:  79%|███████▉  | 23/29 [00:04<00:01,  4.88it/s]
# Generating for node: 23:  83%|████████▎ | 24/29 [00:04<00:01,  4.88it/s]
# Generating for node: 17:  83%|████████▎ | 24/29 [00:04<00:01,  4.88it/s]
# Generating for node: 17:  86%|████████▌ | 25/29 [00:05<00:00,  4.85it/s]
# Generating for node: 14:  86%|████████▌ | 25/29 [00:05<00:00,  4.85it/s]
# Generating for node: 14:  90%|████████▉ | 26/29 [00:05<00:00,  4.91it/s]
# Generating for node: 21:  90%|████████▉ | 26/29 [00:05<00:00,  4.91it/s]
# Generating for node: 21:  93%|█████████▎| 27/29 [00:05<00:00,  4.96it/s]
# Generating for node: 24:  93%|█████████▎| 27/29 [00:05<00:00,  4.96it/s]
# Generating for node: 24:  97%|█████████▋| 28/29 [00:05<00:00,  4.97it/s]
# Generating for node: 18:  97%|█████████▋| 28/29 [00:05<00:00,  4.97it/s]
# Generating for node: 18: 100%|██████████| 29/29 [00:05<00:00,  4.84it/s]

# %%
x0_synth, y0_synth = samples[0]['x_sample'], samples[0]['y_sample']
x1_synth, y1_synth = samples[1]['x_sample'], samples[1]['y_sample']
x2_synth, y2_synth = samples[2]['x_sample'], samples[2]['y_sample']
x3_synth, y3_synth = samples[3]['x_sample'], samples[3]['y_sample']
x4_synth, y4_synth = samples[4]['x_sample'], samples[4]['y_sample']
x5_synth, y5_synth = samples[5]['x_sample'], samples[5]['y_sample']

# %%
samples_smote = []

for prop in proportions :
    o = sv.SMOTE(proportion = prop,
                   random_state = random_state)
    
    print(prop)
    x_g, y_g = o.sample(X_train,y_train)
    
    f_dict = {
        'prop':prop,
        'x_sample':x_g,
        'y_sample':y_g
    }
    
    samples_smote.append(f_dict)
# Out:
# 2021-06-07 12:03:02,668:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:02,668:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:02,668:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:02,778:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:02,778:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:02,778:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 0.1
# 0.3
# 2021-06-07 12:03:03,015:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:03,015:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:03,015:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 0.5
# 2021-06-07 12:03:03,394:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:03,394:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:03,394:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 0.7
# 2021-06-07 12:03:03,947:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:03,947:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:03,947:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 0.9
# 2021-06-07 12:03:04,660:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:04,660:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 2021-06-07 12:03:04,660:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 4}")
# 1

# %%
x0_smote, y0_smote = samples_smote[0]['x_sample'], samples_smote[0]['y_sample']
x1_smote, y1_smote = samples_smote[1]['x_sample'], samples_smote[1]['y_sample']
x2_smote, y2_smote = samples_smote[2]['x_sample'], samples_smote[2]['y_sample']
x3_smote, y3_smote = samples_smote[3]['x_sample'], samples_smote[3]['y_sample']
x4_smote, y4_smote = samples_smote[4]['x_sample'], samples_smote[4]['y_sample']
x5_smote, y5_smote = samples_smote[5]['x_sample'], samples_smote[5]['y_sample']

# %%
def pca_plot(X,y) :
    
    x = StandardScaler().fit_transform(X)

    pca = PCA(n_components=2)
    principalComponents = pca.fit_transform(x)
    principalDf = pd.DataFrame(data = principalComponents
                 , columns = ['principal component 1', 'principal component 2'])
    
    fig = plt.figure(figsize = (12,7))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1')
    ax.set_ylabel('Principal Component 2')
    ax.set_title(f'2 component PCA')

    counter = Counter(y)

    for label, _ in counter.items() :
        rowix = np.where(y == label)[0]
        ax.scatter(principalComponents[rowix, 0], principalComponents[rowix, 1], label=str(label))

    ax.legend()

    fig.show()
    print(counter)

# %%
pca_plot(x0_synth,y0_synth)
plt.title("2 Component PCA: Synthsonic")
# Out:
# Counter({0: 190475, 1: 19358})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: Synthsonic')

# %%
pca_plot(x1_synth,y1_synth)
plt.title("2 Component PCA: Synthsonic")
# Out:
# Counter({0: 190475, 1: 57384})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: Synthsonic')

# %%
pca_plot(x2_synth,y2_synth)
plt.title("2 Component PCA: Synthsonic")
# Out:
# Counter({0: 190475, 1: 95410})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: Synthsonic')

# %%
pca_plot(x3_synth,y3_synth)
plt.title("2 Component PCA: Synthsonic")
# Out:
# Counter({0: 190475, 1: 133436})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: Synthsonic')

# %%
pca_plot(x4_synth,y4_synth)
plt.title("2 Component PCA: Synthsonic")
# Out:
# Counter({0: 190475, 1: 171462})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: Synthsonic')

# %%
pca_plot(x5_synth,y5_synth)
plt.title("2 Component PCA: Synthsonic")
# Out:
# Counter({0: 190475, 1: 190475})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: Synthsonic')

# %%
pca_plot(x0_smote,y0_smote)
plt.title("2 Component PCA: SMOTE")
# Out:
# Counter({0: 190475, 1: 19358})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: SMOTE')

# %%
pca_plot(x1_smote,y1_smote)
plt.title("2 Component PCA: SMOTE")
# Out:
# Counter({0: 190475, 1: 57384})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: SMOTE')

# %%
pca_plot(x2_smote,y2_smote)
plt.title("2 Component PCA: SMOTE")
# Out:
# Counter({0: 190475, 1: 95410})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: SMOTE')

# %%
pca_plot(x3_smote,y3_smote)
plt.title("2 Component PCA: SMOTE")
# Out:
# Counter({0: 190475, 1: 133436})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: SMOTE')

# %%
pca_plot(x4_smote,y4_smote)
plt.title("2 Component PCA: SMOTE")
# Out:
# Counter({0: 190475, 1: 171462})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: SMOTE')

# %%
pca_plot(x5_smote,y5_smote)
plt.title("2 Component PCA: SMOTE")
# Out:
# Counter({0: 190475, 1: 190475})
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Text(0.5, 1.0, '2 Component PCA: SMOTE')

# %% [markdown]
# # Evaluation of oversamplers

# %%
proportions = [0.1,0.3,0.5,0.7,0.9,1]
xs_synth = [x0_synth,x1_synth,x2_synth,x3_synth,x4_synth,x5_synth]
ys_synth = [y0_synth,y1_synth,y2_synth,y3_synth,y4_synth,y5_synth]

# %%
clf = DecisionTreeClassifier(random_state=random_state)

res = []

for prop,data,target in zip(proportions,xs_synth,ys_synth) :
    
    clf.fit(data,target)
    
    prediction = clf.predict(X_test)
    proba = clf.predict_proba(X_test)[:,1]
    
    f_dict = {
    'proportion':prop,
    'clf_score': clf.score(X_test,y_test),
    'accuracy': accuracy_score(y_test, prediction),
    'balanced acc': balanced_accuracy_score(y_test,prediction),
    'recall': recall_score(y_test,prediction),
    'roc_auc_score': roc_auc_score(y_test, proba),
    'f1_score': f1_score(y_test, prediction, average='binary'),
    'geometric mean': geometric_mean_score(y_test, prediction)
    }

    res.append(f_dict)
    
resultdf = pd.DataFrame(res)
resultdf
# Out:
#    proportion  clf_score  accuracy  balanced acc    recall  roc_auc_score  \
# 0         0.1   0.999011  0.999011      0.863663  0.727891       0.863599
# 1         0.3   0.998872  0.998872      0.860198  0.721088       0.860134
# 2         0.5   0.999064  0.999064      0.856898  0.714286       0.856835
# 3         0.7   0.999053  0.999053      0.884061  0.768707       0.884010
# 4         0.9   0.999000  0.999000      0.890826  0.782313       0.890774
# 5         1.0   0.998968  0.998968      0.884018  0.768707       0.883968
#
#    f1_score  geometric mean
# 0  0.697068        0.852924
# 1  0.666667        0.848875
# 2  0.704698        0.844947
# 3  0.717460        0.876503
# 4  0.709877        0.884192
# 5  0.699690        0.876465

# %%
clf.score(X_train,y_train)
# Out:
# 0.999973797295881

# %%
clf = DecisionTreeClassifier(random_state=random_state)

clf.fit(x1_synth,y1_synth)

prediction = clf.predict(X_test)
proba = clf.predict_proba(X_test)[:,1]

res = []
    
f_dict = {
    'proportion':proportions[1],
    'clf_score': clf.score(X_test,y_test),
    'accuracy': accuracy_score(y_test, prediction),
    'balanced acc': balanced_accuracy_score(y_test,prediction),
    'recall': recall_score(y_test,prediction),
    'roc_auc_score': roc_auc_score(y_test, proba),
    'f1_score': f1_score(y_test, prediction, average='binary'),
    'geometric mean': geometric_mean_score(y_test, prediction)
}

res.append(f_dict)

res
# Out:
# [{'proportion': 0.3,
#   'clf_score': 0.9988721844510411,
#   'accuracy': 0.9988721844510411,
#   'balanced acc': 0.8601978835012266,
#   'recall': 0.7210884353741497,
#   'roc_auc_score': 0.8601339811286834,
#   'f1_score': 0.6666666666666667,
#   'geometric mean': 0.8488751146203839}]
