# %%
import numpy as np
import pandas as pd
import pathlib
import sys
sys.path.append(str(pathlib.Path.cwd().parents[1]))
from handle_data import HandleData
from evaluate_oversampler_cross_val import cross_validation

# oversamplers
from imblearn.over_sampling import RandomOverSampler, SMOTE, SMOTENC, SVMSMOTE, ADASYN, BorderlineSMOTE
from sv_synthsonic import synthsonic
import smote_variants as sv

# classifiers
from xgboost.sklearn import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
datafolder = pathlib.Path.cwd().parents[1] / 'Datasets'
train = pd.read_csv(datafolder.joinpath('train.csv'),index_col=0)
test = pd.read_csv(datafolder.joinpath('test.csv'),index_col=0)

# %%
train.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name          int64
# Sex           int64
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket        int64
# Fare        float64
# Cabin         int64
# Embarked     object
# dtype: object

# %%
train['Cabin'] = train.Cabin.astype(str)
train['Embarked'] = train.Embarked.astype(str)
train = HandleData().label_encode(train, ['Name','Sex','Ticket','Cabin','Embarked'])
train.Cabin = train.Cabin.astype(float)
train.Embarked = train.Embarked.astype(float)

# %%
X = train.iloc[:,1:].values
y = train.iloc[:,0].values
title = 'Titanic'

# %%
random_state=5
oversamplers = [RandomOverSampler(random_state=random_state), 
                SMOTE(random_state=random_state, n_jobs=-1),
                SMOTENC(categorical_features=[],random_state=random_state),
                SVMSMOTE(random_state=random_state, n_jobs=-1), 
                ADASYN(random_state=random_state, n_jobs=-1), 
                BorderlineSMOTE(random_state=random_state, n_jobs=-1),
                synthsonic(distinct_threshold=20),
                sv.polynom_fit_SMOTE(random_state=random_state),
                sv.Random_SMOTE(random_state=random_state),
                sv.NoSMOTE()]
proportions = np.array([0.2, 0.4, 0.6, 0.8, 1.])
respath = pathlib.Path.cwd() / 'CSV_results' / 'Cross_validation' / 'cross_validation_titanic.csv'

# %%
cv = cross_validation()
cv.loop_over_oversamplers(X,y,title, oversamplers, proportions)
# Out:
# oversampler:  60%|██████    | 6/10 [00:08<00:06,  1.68s/it]2021-07-30 12:15:07,081:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:07,081:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (257). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 1622.53it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  9.69it/s]
# Generating for node: 5:  22%|██▏       | 2/9 [00:00<00:00,  9.69it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 5:  33%|███▎      | 3/9 [00:00<00:00,  6.80it/s]
# Generating for node: 7:  33%|███▎      | 3/9 [00:00<00:00,  6.80it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00,  5.35it/s]
# Generating for node: 2:  44%|████▍     | 4/9 [00:00<00:00,  5.35it/s]
# Generating for node: 2:  56%|█████▌    | 5/9 [00:00<00:00,  4.77it/s]
# Generating for node: 3:  56%|█████▌    | 5/9 [00:00<00:00,  4.77it/s]
# Generating for node: 3:  67%|██████▋   | 6/9 [00:01<00:00,  4.44it/s]
# Generating for node: 6:  67%|██████▋   | 6/9 [00:01<00:00,  4.44it/s]
# Generating for node: 6:  78%|███████▊  | 7/9 [00:01<00:00,  4.33it/s]
# Generating for node: 8:  78%|███████▊  | 7/9 [00:01<00:00,  4.33it/s]
# Generating for node: 8:  89%|████████▉ | 8/9 [00:01<00:00,  4.35it/s]
# Generating for node: 4:  89%|████████▉ | 8/9 [00:01<00:00,  4.35it/s]
# Generating for node: 4: 100%|██████████| 9/9 [00:01<00:00,  4.82it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 5:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 7:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 35.67it/s]
# Generating for node: 2:  44%|████▍     | 4/9 [00:00<00:00, 35.67it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 35.67it/s]
# Generating for node: 6:  44%|████▍     | 4/9 [00:00<00:00, 35.67it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 35.67it/s]
# Generating for node: 8:  89%|████████▉ | 8/9 [00:00<00:00, 20.25it/s]
# Generating for node: 4: 100%|██████████| 9/9 [00:00<00:00, 20.73it/s]
# 2021-07-30 12:15:11,395:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:11,395:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (256). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 2745.93it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  9.75it/s]
# Generating for node: 6:  22%|██▏       | 2/9 [00:00<00:00,  9.75it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 6:  33%|███▎      | 3/9 [00:00<00:00,  6.59it/s]
# Generating for node: 3:  33%|███▎      | 3/9 [00:00<00:00,  6.59it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00,  5.19it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00,  5.19it/s]
# Generating for node: 4:  56%|█████▌    | 5/9 [00:00<00:00,  4.77it/s]
# Generating for node: 8:  56%|█████▌    | 5/9 [00:00<00:00,  4.77it/s]
# Generating for node: 8:  67%|██████▋   | 6/9 [00:01<00:00,  4.57it/s]
# Generating for node: 7:  67%|██████▋   | 6/9 [00:01<00:00,  4.57it/s]
# Generating for node: 7:  78%|███████▊  | 7/9 [00:01<00:00,  4.10it/s]
# Generating for node: 5:  78%|███████▊  | 7/9 [00:01<00:00,  4.10it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:01<00:00,  3.93it/s]
# Generating for node: 2:  89%|████████▉ | 8/9 [00:01<00:00,  3.93it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:01<00:00,  4.50it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 6:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 3:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 38.91it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00, 38.91it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 38.91it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 38.91it/s]
# Generating for node: 5:  44%|████▍     | 4/9 [00:00<00:00, 38.91it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:00<00:00, 19.56it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:00<00:00, 20.29it/s]
# 2021-07-30 12:15:15,540:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:15,540:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (256). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 2917.56it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  8.95it/s]
# Generating for node: 6:  22%|██▏       | 2/9 [00:00<00:00,  8.95it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 6:  33%|███▎      | 3/9 [00:00<00:00,  6.15it/s]
# Generating for node: 8:  33%|███▎      | 3/9 [00:00<00:00,  6.15it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:01,  4.79it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:01,  4.79it/s]
# Generating for node: 7:  56%|█████▌    | 5/9 [00:01<00:00,  4.09it/s]
# Generating for node: 2:  56%|█████▌    | 5/9 [00:01<00:00,  4.09it/s]
# Generating for node: 2:  67%|██████▋   | 6/9 [00:01<00:00,  4.03it/s]
# Generating for node: 4:  67%|██████▋   | 6/9 [00:01<00:00,  4.03it/s]
# Generating for node: 4:  78%|███████▊  | 7/9 [00:01<00:00,  3.97it/s]
# Generating for node: 3:  78%|███████▊  | 7/9 [00:01<00:00,  3.97it/s]
# Generating for node: 3:  89%|████████▉ | 8/9 [00:01<00:00,  3.88it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:01<00:00,  3.88it/s]
# Generating for node: 5: 100%|██████████| 9/9 [00:02<00:00,  3.99it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 6:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 8:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 30.77it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 30.77it/s]
# Generating for node: 2:  44%|████▍     | 4/9 [00:00<00:00, 30.77it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00, 30.77it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 30.77it/s]
# Generating for node: 3:  89%|████████▉ | 8/9 [00:00<00:00, 15.11it/s]
# Generating for node: 5: 100%|██████████| 9/9 [00:00<00:00, 15.42it/s]
# 2021-07-30 12:15:20,262:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:20,262:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 0.8, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (257). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 1742.08it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  8.99it/s]
# Generating for node: 6:  22%|██▏       | 2/9 [00:00<00:00,  8.99it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 6:  33%|███▎      | 3/9 [00:00<00:00,  6.54it/s]
# Generating for node: 4:  33%|███▎      | 3/9 [00:00<00:00,  6.54it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00,  5.49it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00,  5.49it/s]
# Generating for node: 3:  56%|█████▌    | 5/9 [00:00<00:00,  4.89it/s]
# Generating for node: 8:  56%|█████▌    | 5/9 [00:00<00:00,  4.89it/s]
# Generating for node: 8:  67%|██████▋   | 6/9 [00:01<00:00,  4.63it/s]
# Generating for node: 7:  67%|██████▋   | 6/9 [00:01<00:00,  4.63it/s]
# Generating for node: 7:  78%|███████▊  | 7/9 [00:01<00:00,  4.33it/s]
# Generating for node: 5:  78%|███████▊  | 7/9 [00:01<00:00,  4.33it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:01<00:00,  3.98it/s]
# Generating for node: 2:  89%|████████▉ | 8/9 [00:01<00:00,  3.98it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:01<00:00,  4.61it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 6:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 4:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00, 36.01it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 36.01it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 36.01it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 36.01it/s]
# Generating for node: 5:  44%|████▍     | 4/9 [00:00<00:00, 36.01it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:00<00:00, 18.27it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:00<00:00, 19.16it/s]
# 2021-07-30 12:15:24,461:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:24,461:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (257). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 2014.52it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  9.34it/s]
# Generating for node: 5:  22%|██▏       | 2/9 [00:00<00:00,  9.34it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 5:  33%|███▎      | 3/9 [00:00<00:00,  6.98it/s]
# Generating for node: 7:  33%|███▎      | 3/9 [00:00<00:00,  6.98it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00,  5.36it/s]
# Generating for node: 2:  44%|████▍     | 4/9 [00:00<00:00,  5.36it/s]
# Generating for node: 2:  56%|█████▌    | 5/9 [00:00<00:00,  4.98it/s]
# Generating for node: 3:  56%|█████▌    | 5/9 [00:00<00:00,  4.98it/s]
# Generating for node: 3:  67%|██████▋   | 6/9 [00:01<00:00,  4.49it/s]
# Generating for node: 6:  67%|██████▋   | 6/9 [00:01<00:00,  4.49it/s]
# Generating for node: 6:  78%|███████▊  | 7/9 [00:01<00:00,  4.09it/s]
# Generating for node: 8:  78%|███████▊  | 7/9 [00:01<00:00,  4.09it/s]
# Generating for node: 8:  89%|████████▉ | 8/9 [00:01<00:00,  4.14it/s]
# Generating for node: 4:  89%|████████▉ | 8/9 [00:01<00:00,  4.14it/s]
# Generating for node: 4: 100%|██████████| 9/9 [00:01<00:00,  4.70it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 5:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 7:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 36.03it/s]
# Generating for node: 2:  44%|████▍     | 4/9 [00:00<00:00, 36.03it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 36.03it/s]
# Generating for node: 6:  44%|████▍     | 4/9 [00:00<00:00, 36.03it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 36.03it/s]
# Generating for node: 8:  89%|████████▉ | 8/9 [00:00<00:00, 19.20it/s]
# Generating for node: 4: 100%|██████████| 9/9 [00:00<00:00, 18.13it/s]
# 2021-07-30 12:15:28,841:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:28,841:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (256). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 2201.98it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  8.03it/s]
# Generating for node: 6:  22%|██▏       | 2/9 [00:00<00:00,  8.03it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 6:  33%|███▎      | 3/9 [00:00<00:01,  4.95it/s]
# Generating for node: 3:  33%|███▎      | 3/9 [00:00<00:01,  4.95it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:01,  4.01it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:01,  4.01it/s]
# Generating for node: 4:  56%|█████▌    | 5/9 [00:01<00:01,  3.82it/s]
# Generating for node: 8:  56%|█████▌    | 5/9 [00:01<00:01,  3.82it/s]
# Generating for node: 8:  67%|██████▋   | 6/9 [00:01<00:00,  3.73it/s]
# Generating for node: 7:  67%|██████▋   | 6/9 [00:01<00:00,  3.73it/s]
# Generating for node: 7:  78%|███████▊  | 7/9 [00:01<00:00,  3.54it/s]
# Generating for node: 5:  78%|███████▊  | 7/9 [00:01<00:00,  3.54it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:02<00:00,  3.57it/s]
# Generating for node: 2:  89%|████████▉ | 8/9 [00:02<00:00,  3.57it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:02<00:00,  3.94it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 6:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 3:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 39.80it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00, 39.80it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 39.80it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 39.80it/s]
# Generating for node: 5:  44%|████▍     | 4/9 [00:00<00:00, 39.80it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:00<00:00, 19.93it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:00<00:00, 20.66it/s]
# 2021-07-30 12:15:33,672:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:33,672:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (256). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 2709.75it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  9.38it/s]
# Generating for node: 6:  22%|██▏       | 2/9 [00:00<00:00,  9.38it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 6:  33%|███▎      | 3/9 [00:00<00:00,  6.60it/s]
# Generating for node: 8:  33%|███▎      | 3/9 [00:00<00:00,  6.60it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00,  5.19it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00,  5.19it/s]
# Generating for node: 7:  56%|█████▌    | 5/9 [00:00<00:00,  4.49it/s]
# Generating for node: 2:  56%|█████▌    | 5/9 [00:00<00:00,  4.49it/s]
# Generating for node: 2:  67%|██████▋   | 6/9 [00:01<00:00,  4.30it/s]
# Generating for node: 4:  67%|██████▋   | 6/9 [00:01<00:00,  4.30it/s]
# Generating for node: 4:  78%|███████▊  | 7/9 [00:01<00:00,  4.22it/s]
# Generating for node: 3:  78%|███████▊  | 7/9 [00:01<00:00,  4.22it/s]
# Generating for node: 3:  89%|████████▉ | 8/9 [00:01<00:00,  4.19it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:01<00:00,  4.19it/s]
# Generating for node: 5: 100%|██████████| 9/9 [00:01<00:00,  4.56it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 6:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 8:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 39.02it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 39.02it/s]
# Generating for node: 2:  44%|████▍     | 4/9 [00:00<00:00, 39.02it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00, 39.02it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 39.02it/s]
# Generating for node: 3:  89%|████████▉ | 8/9 [00:00<00:00, 20.40it/s]
# Generating for node: 5: 100%|██████████| 9/9 [00:00<00:00, 20.53it/s]
# 2021-07-30 12:15:37,953:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# 2021-07-30 12:15:37,953:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1.0, 'distinct_threshold': 20, 'do_PCA': True, 'ordering': 'pca'}")
# n_quantiles (500) is greater than the total number of samples (257). n_quantiles is set to num samples.
#
#   0%|          | 0/28.0 [00:00<?, ?it/s]
# Building tree: 100%|██████████| 28/28.0 [00:00<00:00, 1612.82it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:  22%|██▏       | 2/9 [00:00<00:00,  9.09it/s]
# Generating for node: 6:  22%|██▏       | 2/9 [00:00<00:00,  9.09it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
# Generating for node: 6:  33%|███▎      | 3/9 [00:00<00:00,  6.44it/s]
# Generating for node: 4:  33%|███▎      | 3/9 [00:00<00:00,  6.44it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00,  5.33it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00,  5.33it/s]
# Generating for node: 3:  56%|█████▌    | 5/9 [00:00<00:00,  4.74it/s]
# Generating for node: 8:  56%|█████▌    | 5/9 [00:00<00:00,  4.74it/s]
# Generating for node: 8:  67%|██████▋   | 6/9 [00:01<00:00,  4.53it/s]
# Generating for node: 7:  67%|██████▋   | 6/9 [00:01<00:00,  4.53it/s]
# Generating for node: 7:  78%|███████▊  | 7/9 [00:01<00:00,  4.17it/s]
# Generating for node: 5:  78%|███████▊  | 7/9 [00:01<00:00,  4.17it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:01<00:00,  3.92it/s]
# Generating for node: 2:  89%|████████▉ | 8/9 [00:01<00:00,  3.92it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:02<00:00,  4.39it/s]
#
#   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 1:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 0:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 6:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 4:   0%|          | 0/9 [00:00<?, ?it/s]
# Generating for node: 4:  44%|████▍     | 4/9 [00:00<00:00, 32.48it/s]
# Generating for node: 3:  44%|████▍     | 4/9 [00:00<00:00, 32.48it/s]
# Generating for node: 8:  44%|████▍     | 4/9 [00:00<00:00, 32.48it/s]
# Generating for node: 7:  44%|████▍     | 4/9 [00:00<00:00, 32.48it/s]
# Generating for node: 5:  44%|████▍     | 4/9 [00:00<00:00, 32.48it/s]
# Generating for node: 5:  89%|████████▉ | 8/9 [00:00<00:00, 16.26it/s]
# Generating for node: 2: 100%|██████████| 9/9 [00:00<00:00, 17.30it/s]
# oversampler:  70%|███████   | 7/10 [00:44<00:38, 12.69s/it]2021-07-30 12:15:42,417:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,417:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,531:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,531:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,639:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,639:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,741:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,741:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 0.8, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,864:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,864:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,978:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:42,978:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:43,095:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:43,095:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:43,211:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# 2021-07-30 12:15:43,211:INFO:polynom_fit_SMOTE: Running sampling via ('polynom_fit_SMOTE', "{'proportion': 1.0, 'topology': 'star', 'random_state': 5}")
# oversampler:  80%|████████  | 8/10 [00:44<00:17,  8.94s/it]2021-07-30 12:15:43,329:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,329:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,439:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,439:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,549:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,549:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,655:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,655:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.8, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,785:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,785:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,900:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:43,900:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:44,010:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:44,010:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:44,128:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-07-30 12:15:44,128:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1.0, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# oversampler:  90%|█████████ | 9/10 [00:45<00:06,  6.43s/it]2021-07-30 12:15:44,254:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,254:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,343:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,343:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,448:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,448:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,555:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,555:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,663:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,663:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,772:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,772:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,873:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,873:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,967:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# 2021-07-30 12:15:44,967:INFO:NoSMOTE: Running sampling via ('NoSMOTE', '{}')
# oversampler: 100%|██████████| 10/10 [00:46<00:00,  4.67s/it]
#    dataset                                        oversampler  proportion  \
# 0  Titanic  RandomOverSampler(random_state=5, sampling_str...         0.8
# 0  Titanic  RandomOverSampler(random_state=5, sampling_str...         1.0
# 0  Titanic  SMOTE(n_jobs=-1, random_state=5, sampling_stra...         0.8
# 0  Titanic  SMOTE(n_jobs=-1, random_state=5, sampling_stra...         1.0
# 0  Titanic  SMOTENC(categorical_features=[0, 2, 3, 4, 8], ...         0.8
# 0  Titanic  SMOTENC(categorical_features=[0, 2, 3, 4, 8], ...         1.0
# 0  Titanic  SVMSMOTE(n_jobs=-1, random_state=5, sampling_s...         0.8
# 0  Titanic  SVMSMOTE(n_jobs=-1, random_state=5, sampling_s...         1.0
# 0  Titanic  ADASYN(n_jobs=-1, random_state=5, sampling_str...         0.8
# 0  Titanic  ADASYN(n_jobs=-1, random_state=5, sampling_str...         1.0
# 0  Titanic  BorderlineSMOTE(n_jobs=-1, random_state=5, sam...         0.8
# 0  Titanic  BorderlineSMOTE(n_jobs=-1, random_state=5, sam...         1.0
# 0  Titanic  ('synthsonic', "{'proportion': 1.0, 'distinct_...         0.8
# 0  Titanic  ('synthsonic', "{'proportion': 1.0, 'distinct_...         1.0
# 0  Titanic  ('polynom_fit_SMOTE', "{'proportion': 1.0, 'to...         0.8
# 0  Titanic  ('polynom_fit_SMOTE', "{'proportion': 1.0, 'to...         1.0
# 0  Titanic  ('Random_SMOTE', "{'proportion': 1.0, 'n_neigh...         0.8
# 0  Titanic  ('Random_SMOTE', "{'proportion': 1.0, 'n_neigh...         1.0
# 0  Titanic                                  ('NoSMOTE', '{}')         0.8
# 0  Titanic                                  ('NoSMOTE', '{}')         1.0
#
#    balanced_accuracy  balanced_accuracy_std    G_mean  G_mean_std        f1  \
# 0           0.769459               0.014219  0.765249    0.013615  0.714238
# 0           0.769823               0.015307  0.766715    0.014771  0.715514
# 0           0.764018               0.020590  0.761144    0.020710  0.708846
# 0           0.768710               0.015535  0.765105    0.014787  0.713844
# 0           0.763831               0.015750  0.760779    0.013828  0.708663
# 0           0.766975               0.019028  0.764513    0.017808  0.713160
# 0           0.773359               0.017938  0.770430    0.016514  0.720552
# 0           0.784563               0.024835  0.781796    0.025143  0.733928
# 0           0.774408               0.020807  0.770786    0.019147  0.721400
# 0           0.768944               0.017013  0.765659    0.015652  0.714737
# 0           0.782261               0.013068  0.779599    0.012114  0.731306
# 0           0.770615               0.012223  0.767951    0.010860  0.717118
# 0           0.771184               0.012726  0.767082    0.010476  0.717101
# 0           0.766197               0.011109  0.763280    0.009982  0.711306
# 0           0.762168               0.013116  0.757015    0.012339  0.704453
# 0           0.762168               0.013116  0.757015    0.012339  0.704453
# 0           0.769642               0.023784  0.765954    0.022354  0.715414
# 0           0.766575               0.018551  0.763369    0.016863  0.711906
# 0           0.766535               0.018999  0.761928    0.017362  0.710704
# 0           0.766535               0.018999  0.761928    0.017362  0.710704
#
#      f1_std  precision  precision_std    recall  recall_std    pr_auc  \
# 0  0.017994   0.740948       0.032630  0.690048    0.013141  0.808083
# 0  0.019357   0.730519       0.032773  0.701710    0.013945  0.801127
# 0  0.026237   0.715223       0.041033  0.704685    0.035508  0.789124
# 0  0.019483   0.733772       0.036211  0.695862    0.015086  0.785233
# 0  0.018883   0.720702       0.046339  0.698837    0.009287  0.795342
# 0  0.022516   0.717971       0.047652  0.710534    0.017007  0.782599
# 0  0.021616   0.733113       0.048552  0.710568    0.016475  0.800666
# 0  0.031558   0.747341       0.040696  0.722093    0.035387  0.800008
# 0  0.025559   0.743995       0.052205  0.701744    0.006103  0.802566
# 0  0.020861   0.730191       0.045659  0.701778    0.017136  0.792359
# 0  0.016359   0.744646       0.034285  0.719289    0.008384  0.807130
# 0  0.014709   0.725611       0.039063  0.710568    0.016475  0.795162
# 0  0.015224   0.740093       0.051244  0.698906    0.025797  0.795834
# 0  0.013616   0.722321       0.033098  0.701744    0.013132  0.786908
# 0  0.016229   0.737351       0.034966  0.675479    0.016388  0.800178
# 0  0.016229   0.737351       0.034966  0.675479    0.016388  0.800178
# 0  0.029339   0.737613       0.053804  0.695862    0.009611  0.791670
# 0  0.022547   0.727139       0.048212  0.698837    0.004319  0.802800
# 0  0.023590   0.740923       0.048626  0.684200    0.008521  0.795476
# 0  0.023590   0.740923       0.048626  0.684200    0.008521  0.795476
#
#    pr_auc_std   runtime  runtime_std
# 0    0.018514  0.000803     0.000018
# 0    0.026958  0.000789     0.000026
# 0    0.022605  0.003240     0.002082
# 0    0.020463  0.002027     0.000047
# 0    0.014956  0.045698     0.006304
# 0    0.019360  0.045819     0.000393
# 0    0.019064  0.226645     0.007007
# 0    0.012864  0.227878     0.002395
# 0    0.024207  0.212220     0.001400
# 0    0.012592  0.212584     0.002438
# 0    0.018355  0.107019     0.001731
# 0    0.033528  0.107012     0.001231
# 0    0.014990  4.255868     0.215427
# 0    0.012512  4.379811     0.218678
# 0    0.021579  0.003833     0.000113
# 0    0.021579  0.003648     0.000100
# 0    0.023594  0.010579     0.000243
# 0    0.017639  0.013674     0.001077
# 0    0.019139  0.001384     0.000068
# 0    0.019139  0.001428     0.000090
