# %%
import sys
import os

sys.path.append('/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis')

result_path = '/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/CSV_results/'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import logging

from collections import Counter

import csv

import xgboost as xgb

from imblearn.datasets import fetch_datasets

from Evaluation import synthsonic

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA

import smote_variants as sv

# %%
# metrics 
from imblearn.metrics import geometric_mean_score, classification_report_imbalanced

from sklearn.model_selection import cross_validate, train_test_split
from sklearn.metrics import (recall_score, roc_auc_score, confusion_matrix, precision_score, precision_recall_curve,
                             f1_score, balanced_accuracy_score, accuracy_score, average_precision_score)

# %%
datasets = fetch_datasets()

# %%
datasets.keys()
# Out:
# odict_keys(['ecoli', 'optical_digits', 'satimage', 'pen_digits', 'abalone', 'sick_euthyroid', 'spectrometer', 'car_eval_34', 'isolet', 'us_crime', 'yeast_ml8', 'scene', 'libras_move', 'thyroid_sick', 'coil_2000', 'arrhythmia', 'solar_flare_m0', 'oil', 'car_eval_4', 'wine_quality', 'letter_img', 'yeast_me2', 'webpage', 'ozone_level', 'mammography', 'protein_homo', 'abalone_19'])

# %%
['spectrometer', 'car_eval_34', 'isolet', 'us_crime', 'yeast_ml8', 'scene', 'libras_move', 'thyroid_sick', 'coil_2000', 'arrhythmia', 'solar_flare_m0', 'oil', 'car_eval_4', 'wine_quality', 'letter_img', 'yeast_me2', 'webpage', 'ozone_level', 'mammography', 'protein_homo', 'abalone_19']

# %%
# params
clf = xgb.XGBClassifier(verbosity=0)
random_state = 5
oversamplers=[sv.Borderline_SMOTE1, sv.ADASYN, sv.polynom_fit_SMOTE, sv.SVM_balance, sv.Random_SMOTE]

# %%
# functions

def load_data(name) :
    
    data = datasets[name]

    X,y,title = data['data'], data['target'], data['DESCR']
    
    return X, y, title

def metrics_test(dataset_name, X_train, X_test, y_train, y_test, clf) :
        
    clf.fit(X_train,y_train)
    
    prediction = clf.predict(X_test)
    proba = clf.predict_proba(X_test)[:,1]

    f_dict = {
        'name':dataset_name,
        'balanced acc': balanced_accuracy_score(y_test,prediction),
        'precision': precision_score(y_test,prediction),
        'recall': recall_score(y_test,prediction),
        'f1_score': f1_score(y_test, prediction, average='binary'),
        'geometric mean': geometric_mean_score(y_test, prediction),
        'average precision' : average_precision_score(y_test, prediction),
        'clf':clf,
        'prediction': prediction,
        'proba': proba
    }
    
    return f_dict

def metrics_test_samples(dataset_name, samples, X_test, y_test, clf) :
    
    res = []
    
    for gen in samples :
        
        prop,x,y = gen['prop'],gen['x_sample'],gen['y_sample']
    
        clf.fit(x,y)

        prediction = clf.predict(X_test)
        proba = clf.predict_proba(X_test)[:,1]

        f_dict = {
            'name':dataset_name,
            'proportion':prop,
            'balanced acc': balanced_accuracy_score(y_test,prediction),
            'precision': precision_score(y_test,prediction),
            'recall': recall_score(y_test,prediction),
            'f1_score': f1_score(y_test, prediction, average='binary'),
            'geometric mean': geometric_mean_score(y_test, prediction),
            'average precision' : average_precision_score(y_test, prediction),
            'clf':clf,
            'prediction': prediction,
            'proba': proba
        }
        
        res.append(f_dict)
        
    return res

def test_dataset(name) :
    
    X,y,title = load_data(name)
        
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = random_state)
        
    result = metrics_test(title, X_train, X_test, y_train, y_test, clf)
        
    return result

def test_dataset_samples(name, proportions) :
    
    X,y,title = load_data(name)
        
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state = random_state)
    
    # create samples
    
    samples = sampler(oversampler, X_train,y_train, proportions)
    
    result = metrics_test_samples(title, samples, X_test, y_test, clf)
    
    return result

def run_multiple(list_datasets,filename) :
    
    results = []
    
    for dataset in list_datasets :
        
        print(dataset)
        
        results.append(test_dataset(dataset))
    
    df = pd.DataFrame(results)
    
    df.to_csv(result_path+filename+".csv")
    
    return df


def run_multiple_samples(oversampler, proportions, list_datasets, filename) :
    
    results = []
    
    for dataset in list_datasets :
        
        print(dataset)    
        results.append(test_dataset_samples(dataset, proportions))
    
    df = pd.DataFrame(results)
    
    df.to_csv(result_path+filename+".csv")
    
    return df


def sampler(oversampler, x, y, proportions) :
    
    samples = []
    
    for prop in proportions :
        o = oversampler(proportion = prop,
                        random_state = random_state)
    
        x_g, y_g = o.sample(x,y)
    
        f_dict = {
            'prop':prop,
            'x_sample':x_g,
            'y_sample':y_g
        }

        samples.append(f_dict)
    
    return samples

# %%
proportions = [0.1,0.3,0.5,0.7,0.9,1]

# %%
oversamplers = [sv.SVM_balance, sv.Random_SMOTE]

for oversampler in oversamplers :
    print(oversampler.__name__)
    
    run_multiple_samples(oversampler, proportions, list(datasets.keys()), oversampler.__name__)
# Out:
# 2021-06-15 17:45:51,013:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,013:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,015:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:45:51,015:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:45:51,019:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,019:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,031:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,031:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,042:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,042:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,055:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,055:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,070:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,070:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,071:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:45:51,071:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:45:51,076:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,076:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,091:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,091:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,104:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,104:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,117:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,117:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,131:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,131:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,133:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:45:51,133:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:45:51,138:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,138:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,154:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,154:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,168:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,168:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,180:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,180:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,195:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,195:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,197:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:45:51,197:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:45:51,202:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,202:INFO:SVM_balance: Evaluating SVM with C=0.010000
# SVM_balance
# ecoli
# 2021-06-15 17:45:51,221:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,221:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,236:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,236:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,249:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,249:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,265:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,265:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,266:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:45:51,266:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:45:51,272:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,272:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,294:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,294:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,309:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,309:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,322:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,322:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,339:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,339:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,340:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:45:51,340:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:45:51,347:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,347:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:45:51,370:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,370:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:45:51,385:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,385:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:45:51,397:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:45:51,397:INFO:SVM_balance: Evaluating SVM with C=10.000000
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 2021-06-15 17:45:51,591:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,591:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:45:51,593:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17
INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:16,600:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:17,288:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:49:17,288:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:49:17,949:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:49:17,949:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:49:17,950:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:49:17,950:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:49:17,973:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:49:17,973:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:49:19,863:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:49:19,863:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:49:21,138:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:21,138:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:21,924:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:49:21,924:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:49:22,666:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:49:22,666:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:49:22,667:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:49:22,667:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C57C0}")
# 2021-06-15 17:49:22,692:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:49:22,692:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:49:25,034:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:49:25,034:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:49:26,549:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:26,549:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:27,454:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:49:27,454:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:49:28,263:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:49:28,263:INFO:SVM_balance: Running sampling via ('SVM_balance', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-15 17:49:28,264:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:49:28,264:INFO:SMOTE: Running sampling via ('SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': RandomState(MT19937) at 0x7FD5C85C56B0}")
# 2021-06-15 17:49:28,291:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:49:28,291:INFO:SVM_balance: Evaluating SVM with C=0.010000
# 2021-06-15 17:49:30,852:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:49:30,852:INFO:SVM_balance: Evaluating SVM with C=0.100000
# 2021-06-15 17:49:32,513:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:32,513:INFO:SVM_balance: Evaluating SVM with C=1.000000
# 2021-06-15 17:49:33,598:INFO:SVM_balance: Evaluating SVM with C=10.000000
# 2021-06-15 17:49:33,598:INFO:SVM_balance: Evaluating SVM with C=10.000000
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...
# 2021-06-16 09:31:20,194:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:20,194:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# letter_img
# 2021-06-16 09:31:20,412:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:20,412:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:20,713:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:20,713:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:21,120:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:21,120:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:21,624:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:21,624:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 2021-06-16 09:31:25,452:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,452:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,462:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,462:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,487:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,487:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,524:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,524:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,575:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,575:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,637:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:25,637:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# yeast_me2
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# webpage
# 2021-06-16 09:31:26,342:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:26,342:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:26,672:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:26,672:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:27,228:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:27,228:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:28,000:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:28,000:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:28,944:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:28,944:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:30,058:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:31:30,058:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 2021-06-16 09:32:23,226:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,226:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,245:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,245:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,294:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,294:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,356:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,356:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# ozone_level
# 2021-06-16 09:32:23,433:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,433:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,523:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:23,523:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 2021-06-16 09:32:25,529:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:25,529:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:25,582:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:25,582:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:25,727:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# mammography
# 2021-06-16 09:32:25,727:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:25,942:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:25,942:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:26,241:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:26,241:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:26,620:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:26,620:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 2021-06-16 09:32:29,801:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:29,801:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# protein_homo
# 2021-06-16 09:32:30,352:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:30,352:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:31,765:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:31,765:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:33,945:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:33,945:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:36,790:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:36,790:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:40,158:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:32:40,158:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# 2021-06-16 09:35:08,030:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,030:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,057:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,057:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.3, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,106:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,106:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.5, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,185:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,185:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.7, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# abalone_19
# 2021-06-16 09:35:08,296:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,296:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 0.9, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,436:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# 2021-06-16 09:35:08,436:INFO:Random_SMOTE: Running sampling via ('Random_SMOTE', "{'proportion': 1, 'n_neighbors': 5, 'n_jobs': 1, 'random_state': 5}")
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
