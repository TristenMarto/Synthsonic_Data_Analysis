# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from imblearn.datasets import fetch_datasets
from imblearn.over_sampling import SMOTE
from collections import Counter
import os
import sys
sys.path.append('/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis')
from sklearn.preprocessing import StandardScaler, LabelEncoder, Binarizer
from sklearn.decomposition import PCA
from xgboost.sklearn import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sv_synthsonic import synthsonic, load_data, pca_plot
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve, auc, confusion_matrix
from sklearn.model_selection import train_test_split, StratifiedKFold

# %%
df_info = pd.read_csv("/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/CSV_results/dataset_info.csv", index_col=0)

# %%
list(df_info[df_info['type'] == 'numerical'].index)
# Out:
# ['satimage',
#  'pen_digits',
#  'spectrometer',
#  'yeast_ml8',
#  'scene',
#  'libras_move',
#  'wine_quality',
#  'ozone_level',
#  'mammography',
#  'protein_homo']

# %%
datasets = ['ecoli',
 'wine_quality',
 'mammography']

# %%
X,y,title = load_data(datasets[0])
clf = DecisionTreeClassifier(random_state=5)
over = synthsonic(random_state=5, proportion=1)

# make plots
f, axes = plt.subplots(1, 2, figsize=(12, 7))
f.suptitle(f"PR Curve for standard and oversampled {clf}")

# do kfold cross val and plot the PR curves
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)

y_real = []
y_proba = []
for i, (train_index, test_index) in enumerate(k_fold.split(X,y), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]    

    clf.fit(X_train, y_train)
    probas = clf.predict_proba(X_test)
    precision, recall, _ = precision_recall_curve(y_test, probas[:,1])
    lab = f"Fold {i} AUC = {auc(recall, precision)}"
    axes[0].step(recall, precision, label=lab)
    y_real.append(y_test)
    y_proba.append(probas[:,1])

y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = f"Overall AUC = {auc(recall, precision)}"
axes[0].step(recall, precision, label=lab, lw=2, color='black')
axes[0].set_xlabel('Recall')
axes[0].set_ylabel('Precision')
axes[0].legend(fontsize='small')

# do kfold cross val and plot the PR curves
y_real = []
y_proba = []
for i, (train_index, test_index) in enumerate(k_fold.split(X,y), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]    

    # generate samples
    try :
        X_train, y_train = over.sample(X_train, y_train)

    except :
        X_train, y_train = over.fit_resample(X_train, y_train)

    clf.fit(X_train, y_train)
    probas = clf.predict_proba(X_test)
    precision, recall, _ = precision_recall_curve(y_test, probas[:,1])
    lab = f"Fold {i} AUC = {auc(recall, precision)}"
    axes[1].step(recall, precision, label=lab)
    y_real.append(y_test)
    y_proba.append(probas[:,1])

y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = f"Overall AUC = {auc(recall, precision)}"
axes[1].step(recall, precision, label=lab, lw=2, color='black')
axes[1].set_xlabel('Recall')
axes[1].set_ylabel('Precision')
axes[1].legend(fontsize='small')

f.tight_layout()
# Out:
# 2021-07-14 13:58:02,191:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:58:02,191:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (28). n_quantiles is set to num samples.
#
#
#
#
#   0%|          | 0/15.0 [00:00<?, ?it/s]
#
#
#
# Building tree: 100%|██████████| 15/15.0 [00:00<00:00, 2095.82it/s]A
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:  29%|██▊       | 2/7 [00:00<00:00, 11.02it/s]
#
#
#
# Generating for node: 4:  29%|██▊       | 2/7 [00:00<00:00, 11.02it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 6:  29%|██▊       | 2/7 [00:00<00:00, 11.02it/s]
#
#
#
# Generating for node: 6:  57%|█████▋    | 4/7 [00:00<00:00,  5.32it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00,  5.32it/s]
#
#
#
# Generating for node: 5:  71%|███████▏  | 5/7 [00:00<00:00,  4.62it/s]
#
#
#
# Generating for node: 2:  71%|███████▏  | 5/7 [00:00<00:00,  4.62it/s]
#
#
#
# Generating for node: 2:  86%|████████▌ | 6/7 [00:01<00:00,  4.48it/s]
#
#
#
# Generating for node: 3:  86%|████████▌ | 6/7 [00:01<00:00,  4.48it/s]
#
#
#
# Generating for node: 3: 100%|██████████| 7/7 [00:01<00:00,  4.83it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 4:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 6:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 6:  57%|█████▋    | 4/7 [00:00<00:00, 22.24it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00, 22.24it/s]
#
#
#
# Generating for node: 2:  57%|█████▋    | 4/7 [00:00<00:00, 22.24it/s]
#
#
#
# Generating for node: 3:  57%|█████▋    | 4/7 [00:00<00:00, 22.24it/s]
#
#
#
# Generating for node: 3: 100%|██████████| 7/7 [00:00<00:00, 16.71it/s]
# 2021-07-14 13:58:06,173:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:58:06,173:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (28). n_quantiles is set to num samples.
#
#
#
#
#   0%|          | 0/15.0 [00:00<?, ?it/s]
#
#
#
# Building tree: 100%|██████████| 15/15.0 [00:00<00:00, 2536.26it/s]A
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 0:  29%|██▊       | 2/7 [00:00<00:00, 10.36it/s]
#
#
#
# Generating for node: 3:  29%|██▊       | 2/7 [00:00<00:00, 10.36it/s]
#
#
#
# Generating for node: 5:  29%|██▊       | 2/7 [00:00<00:00, 10.36it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00,  5.37it/s]
#
#
#
# Generating for node: 2:  57%|█████▋    | 4/7 [00:00<00:00,  5.37it/s]
#
#
#
# Generating for node: 2:  71%|███████▏  | 5/7 [00:00<00:00,  4.63it/s]
#
#
#
# Generating for node: 6:  71%|███████▏  | 5/7 [00:00<00:00,  4.63it/s]
#
#
#
# Generating for node: 6:  86%|████████▌ | 6/7 [00:01<00:00,  4.45it/s]
#
#
#
# Generating for node: 4:  86%|████████▌ | 6/7 [00:01<00:00,  4.45it/s]
#
#
#
# Generating for node: 4: 100%|██████████| 7/7 [00:01<00:00,  4.74it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 3:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 5:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00, 21.46it/s]
#
#
#
# Generating for node: 2:  57%|█████▋    | 4/7 [00:00<00:00, 21.46it/s]
#
#
#
# Generating for node: 6:  57%|█████▋    | 4/7 [00:00<00:00, 21.46it/s]
#
#
#
# Generating for node: 4:  57%|█████▋    | 4/7 [00:00<00:00, 21.46it/s]
#
#
#
# Generating for node: 4: 100%|██████████| 7/7 [00:00<00:00, 16.95it/s]
# 2021-07-14 13:58:10,227:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:58:10,227:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (28). n_quantiles is set to num samples.
#
#
#
#
#   0%|          | 0/15.0 [00:00<?, ?it/s]
#
#
#
# Building tree: 100%|██████████| 15/15.0 [00:00<00:00, 1909.86it/s]A
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 0:  29%|██▊       | 2/7 [00:00<00:00, 10.93it/s]
#
#
#
# Generating for node: 6:  29%|██▊       | 2/7 [00:00<00:00, 10.93it/s]
#
#
#
# Generating for node: 5:  29%|██▊       | 2/7 [00:00<00:00, 10.93it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00,  5.56it/s]
#
#
#
# Generating for node: 3:  57%|█████▋    | 4/7 [00:00<00:00,  5.56it/s]
#
#
#
# Generating for node: 3:  71%|███████▏  | 5/7 [00:00<00:00,  5.06it/s]
#
#
#
# Generating for node: 4:  71%|███████▏  | 5/7 [00:00<00:00,  5.06it/s]
# Generating for node: 4:  86%|████████▌ | 6/7 [00:01<00:00,  4.71it/s]
#
#
#
# Generating for node: 2:  86%|████████▌ | 6/7 [00:01<00:00,  4.71it/s]
#
#
#
# Generating for node: 2: 100%|██████████| 7/7 [00:01<00:00,  5.05it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 6:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 5:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00, 23.06it/s]
#
#
#
# Generating for node: 3:  57%|█████▋    | 4/7 [00:00<00:00, 23.06it/s]
#
#
#
# Generating for node: 4:  57%|█████▋    | 4/7 [00:00<00:00, 23.06it/s]
#
#
#
# Generating for node: 2:  57%|█████▋    | 4/7 [00:00<00:00, 23.06it/s]
#
#
#
# Generating for node: 2: 100%|██████████| 7/7 [00:00<00:00, 18.47it/s]
# 2021-07-14 13:58:14,085:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:58:14,085:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (28). n_quantiles is set to num samples.
#
#
#
#
#   0%|          | 0/15.0 [00:00<?, ?it/s]
#
#
#
# Building tree: 100%|██████████| 15/15.0 [00:00<00:00, 1419.10it/s]A
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 0:  29%|██▊       | 2/7 [00:00<00:00, 10.46it/s]
#
#
#
# Generating for node: 2:  29%|██▊       | 2/7 [00:00<00:00, 10.46it/s]
#
#
#
# Generating for node: 3:  29%|██▊       | 2/7 [00:00<00:00, 10.46it/s]
#
#
#
# Generating for node: 3:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00,  5.43it/s]
#
#
#
# Generating for node: 5:  71%|███████▏  | 5/7 [00:00<00:00,  4.89it/s]
#
#
#
# Generating for node: 6:  71%|███████▏  | 5/7 [00:00<00:00,  4.89it/s]
#
#
#
# Generating for node: 6:  86%|████████▌ | 6/7 [00:01<00:00,  4.60it/s]
#
#
#
# Generating for node: 4:  86%|████████▌ | 6/7 [00:01<00:00,  4.60it/s]
#
#
#
# Generating for node: 4: 100%|██████████| 7/7 [00:01<00:00,  4.89it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
#
#
#
#
#   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 1:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
#
#
#
#
# Generating for node: 2:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 3:   0%|          | 0/7 [00:00<?, ?it/s]
#
#
#
# Generating for node: 3:  57%|█████▋    | 4/7 [00:00<00:00, 25.33it/s]
#
#
#
# Generating for node: 5:  57%|█████▋    | 4/7 [00:00<00:00, 25.33it/s]
#
#
#
# Generating for node: 6:  57%|█████▋    | 4/7 [00:00<00:00, 25.33it/s]
#
#
#
# Generating for node: 4:  57%|█████▋    | 4/7 [00:00<00:00, 25.33it/s]
#
#
#
# Generating for node: 4: 100%|██████████| 7/7 [00:00<00:00, 19.37it/s]
# 2021-07-14 13:58:17,895:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:58:17,895:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (28). n_quantiles is set to num samples.
#
#
#
#
#   0%|          | 0/15.0 [00:00<?, ?it/s]
#
#
#
# Building tree:   0%|          | 0/595.0 [28:43<?, ?it/s][A
# Building tree:   0%|          | 0/595.0 [28:48<?, ?it/s]
# Building tree:   0%|          | 0/595.0 [23:18<?, ?it/s]
# Building tree:   0%|          | 0/595.0 [23:13<?, ?it/s]
# Building tree: 100%|██████████| 15/15.0 [00:00<00:00, 151.60it/s]
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
# Generating for node: 6: 100%|██████████| 7/7 [00:01<00:00,  5.22it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Generating for node: 0:   0%|          | 0/7 [00:00<?, ?it/s]/Users/tristenmarto/anaconda3/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:522: UserWarning: Found unknown state name. Trying to switch to using all state names as state numbers
#   "Found unknown state name. Trying to switch to using all state names as state numbers"
# Generating for node: 6: 100%|██████████| 7/7 [00:00<00:00, 19.48it/s]

# %%
X,y,title = load_data(datasets[1])
clf = DecisionTreeClassifier(random_state=5)
over = synthsonic(random_state=5, proportion=1)

# make plots
f, axes = plt.subplots(1, 2, figsize=(12, 7))
f.suptitle(f"PR Curve for standard and oversampled {clf}")

# do kfold cross val and plot the PR curves
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)

y_real = []
y_proba = []
for i, (train_index, test_index) in enumerate(k_fold.split(X,y), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]    

    clf.fit(X_train, y_train)
    probas = clf.predict_proba(X_test)
    precision, recall, _ = precision_recall_curve(y_test, probas[:,1])
    lab = f"Fold {i} AUC = {auc(recall, precision)}"
    axes[0].step(recall, precision, label=lab)
    y_real.append(y_test)
    y_proba.append(probas[:,1])

y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = f"Overall AUC = {auc(recall, precision)}"
axes[0].step(recall, precision, label=lab, lw=2, color='black')
axes[0].set_xlabel('Recall')
axes[0].set_ylabel('Precision')
axes[0].legend(fontsize='small')

# do kfold cross val and plot the PR curves
y_real = []
y_proba = []
for i, (train_index, test_index) in enumerate(k_fold.split(X,y), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]    

    # generate samples
    try :
        X_train, y_train = over.sample(X_train, y_train)

    except :
        X_train, y_train = over.fit_resample(X_train, y_train)

    clf.fit(X_train, y_train)
    probas = clf.predict_proba(X_test)
    precision, recall, _ = precision_recall_curve(y_test, probas[:,1])
    lab = f"Fold {i} AUC = {auc(recall, precision)}"
    axes[1].step(recall, precision, label=lab)
    y_real.append(y_test)
    y_proba.append(probas[:,1])

y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = f"Overall AUC = {auc(recall, precision)}"
axes[1].step(recall, precision, label=lab, lw=2, color='black')
axes[1].set_xlabel('Recall')
axes[1].set_ylabel('Precision')
axes[1].legend(fontsize='small')

f.tight_layout()
# Out:
# 2021-07-14 13:32:58,521:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:32:58,521:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (146). n_quantiles is set to num samples.
#
#
#
#
#   0%|          | 0/45.0 [00:00<?, ?it/s]
#
#
#
# Building tree: 100%|██████████| 45/45.0 [00:00<00:00, 1338.01it/s]A
# Building tree:   0%|          | 0/595.0 [08:04<?, ?it/s]
# Building tree:   0%|          | 0/595.0 [08:09<?, ?it/s]
# Generating for node: 2: 100%|██████████| 11/11 [00:02<00:00,  4.61it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Generating for node: 2: 100%|██████████| 11/11 [00:00<00:00, 15.83it/s]
# 2021-07-14 13:33:05,233:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:33:05,233:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (146). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 45/45.0 [00:00<00:00, 1539.67it/s]
# Generating for node: 8: 100%|██████████| 11/11 [00:02<00:00,  4.58it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Generating for node: 8: 100%|██████████| 11/11 [00:00<00:00, 15.97it/s]
# 2021-07-14 13:33:11,927:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:33:11,927:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (146). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 45/45.0 [00:00<00:00, 1513.63it/s]
# Generating for node: 6: 100%|██████████| 11/11 [00:02<00:00,  4.47it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Generating for node: 6: 100%|██████████| 11/11 [00:00<00:00, 15.81it/s]
# 2021-07-14 13:33:18,546:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:33:18,546:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (147). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 45/45.0 [00:00<00:00, 1718.73it/s]
# Generating for node: 5: 100%|██████████| 11/11 [00:02<00:00,  4.77it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Generating for node: 5: 100%|██████████| 11/11 [00:00<00:00, 15.99it/s]
# 2021-07-14 13:33:25,121:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:33:25,121:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (147). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 45/45.0 [00:00<00:00, 1401.00it/s]
# Generating for node: 10: 100%|██████████| 11/11 [00:02<00:00,  4.72it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Generating for node: 10: 100%|██████████| 11/11 [00:00<00:00, 15.94it/s]

# %%
X,y,title = load_data(datasets[2])
clf = DecisionTreeClassifier(random_state=5)
over = synthsonic(random_state=5, proportion=1)

# make plots
f, axes = plt.subplots(1, 2, figsize=(12, 7))
f.suptitle(f"PR Curve for standard and oversampled {clf}")

# do kfold cross val and plot the PR curves
k_fold = StratifiedKFold(n_splits=5, shuffle=True, random_state=5)

y_real = []
y_proba = []
for i, (train_index, test_index) in enumerate(k_fold.split(X,y), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]    

    clf.fit(X_train, y_train)
    probas = clf.predict_proba(X_test)
    precision, recall, _ = precision_recall_curve(y_test, probas[:,1])
    lab = f"Fold {i} AUC = {auc(recall, precision)}"
    axes[0].step(recall, precision, label=lab)
    y_real.append(y_test)
    y_proba.append(probas[:,1])

y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = f"Overall AUC = {auc(recall, precision)}"
axes[0].step(recall, precision, label=lab, lw=2, color='black')
axes[0].set_xlabel('Recall')
axes[0].set_ylabel('Precision')
axes[0].legend(fontsize='small')

# do kfold cross val and plot the PR curves
y_real = []
y_proba = []
for i, (train_index, test_index) in enumerate(k_fold.split(X,y), 1):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]    

    # generate samples
    try :
        X_train, y_train = over.sample(X_train, y_train)

    except :
        X_train, y_train = over.fit_resample(X_train, y_train)

    clf.fit(X_train, y_train)
    probas = clf.predict_proba(X_test)
    precision, recall, _ = precision_recall_curve(y_test, probas[:,1])
    lab = f"Fold {i} AUC = {auc(recall, precision)}"
    axes[1].step(recall, precision, label=lab)
    y_real.append(y_test)
    y_proba.append(probas[:,1])

y_real = np.concatenate(y_real)
y_proba = np.concatenate(y_proba)
precision, recall, _ = precision_recall_curve(y_real, y_proba)
lab = f"Overall AUC = {auc(recall, precision)}"
axes[1].step(recall, precision, label=lab, lw=2, color='black')
axes[1].set_xlabel('Recall')
axes[1].set_ylabel('Precision')
axes[1].legend(fontsize='small')

f.tight_layout()
# Out:
# 2021-07-14 13:33:59,108:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:33:59,108:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (208). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 10/10.0 [00:00<00:00, 7656.63it/s]
# Generating for node: 5: 100%|██████████| 6/6 [00:01<00:00,  4.91it/s]
# Generating for node: 5: 100%|██████████| 6/6 [00:00<00:00, 17.18it/s]
# 2021-07-14 13:34:03,056:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:34:03,056:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (208). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 10/10.0 [00:00<00:00, 8531.94it/s]
# Generating for node: 4: 100%|██████████| 6/6 [00:01<00:00,  5.28it/s]
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/isotonic.py:71: UserWarning: Confidence interval of the Spearman correlation coefficient spans zero. Determination of ``increasing`` may be suspect.
#   warnings.warn("Confidence interval of the Spearman "
# Generating for node: 4: 100%|██████████| 6/6 [00:00<00:00, 17.18it/s]
# 2021-07-14 13:34:06,870:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:34:06,870:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (208). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 10/10.0 [00:00<00:00, 8292.42it/s]
# Generating for node: 2: 100%|██████████| 6/6 [00:01<00:00,  4.98it/s]
# Generating for node: 2: 100%|██████████| 6/6 [00:00<00:00, 17.33it/s]
# 2021-07-14 13:34:10,724:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:34:10,724:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (208). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 10/10.0 [00:00<00:00, 7293.17it/s]
# Generating for node: 5: 100%|██████████| 6/6 [00:01<00:00,  5.25it/s]
# Generating for node: 5: 100%|██████████| 6/6 [00:00<00:00, 17.31it/s]
# 2021-07-14 13:34:14,393:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# 2021-07-14 13:34:14,393:INFO:synthsonic: Running sampling via ('synthsonic', "{'proportion': 1, 'distinct_threshold': -1, 'random_state': 5, 'do_PCA': True}")
# n_quantiles (500) is greater than the total number of samples (208). n_quantiles is set to num samples.
# Building tree: 100%|██████████| 10/10.0 [00:00<00:00, 7199.29it/s]
# Generating for node: 3: 100%|██████████| 6/6 [00:01<00:00,  5.17it/s]
# Generating for node: 3: 100%|██████████| 6/6 [00:00<00:00, 17.31it/s]
