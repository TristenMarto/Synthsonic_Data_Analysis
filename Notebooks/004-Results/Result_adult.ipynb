# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pathlib
import sys
sys.path.append(str(pathlib.Path.cwd().parent.parent))
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_recall_curve, plot_precision_recall_curve, auc
from sklearn.model_selection import StratifiedKFold

from imblearn.metrics import geometric_mean_score, classification_report_imbalanced
from sklearn.metrics import (recall_score, roc_auc_score, confusion_matrix, precision_score, precision_recall_curve,
                             f1_score, balanced_accuracy_score, accuracy_score, auc)

# %%
home_folder = pathlib.Path.cwd().parent.parent
path = home_folder.joinpath(home_folder, 'CSV_results')
df_info = pd.read_csv(path.joinpath('dataset_info.csv'))
df = pd.read_csv(path.joinpath('Cross_validation', 'cross_validation_adult.csv'), index_col=0).reset_index(drop=True)

# %%
a = df.oversampler.unique()
b = ['RandomOverSampler', 
     'SMOTE', 
     'SMOTENC', 
     'SVMSMOTE', 
     'ADASYN', 
     'BorderlineSMOTE', 
     'synthsonic', 
     'polynom_fit_SMOTE',
     'Random_SMOTE',
     'NoSMOTE']

for old, new in zip(a,b) :
    df.loc[df.oversampler == old, 'oversampler'] = new

df
# Out:
#    dataset        oversampler  proportion  balanced_accuracy  \
# 0    Adult  RandomOverSampler         0.4           0.815048
# 1    Adult  RandomOverSampler         0.6           0.830358
# 2    Adult  RandomOverSampler         0.8           0.836210
# 3    Adult  RandomOverSampler         1.0           0.839240
# 4    Adult              SMOTE         0.4           0.813286
# 5    Adult              SMOTE         0.6           0.826564
# 6    Adult              SMOTE         0.8           0.830627
# 7    Adult              SMOTE         1.0           0.832816
# 8    Adult            SMOTENC         0.4           0.810865
# 9    Adult            SMOTENC         0.6           0.818624
# 10   Adult            SMOTENC         0.8           0.820361
# 11   Adult            SMOTENC         1.0           0.822083
# 12   Adult           SVMSMOTE         0.4           0.816173
# 13   Adult           SVMSMOTE         0.6           0.829978
# 14   Adult           SVMSMOTE         0.8           0.834498
# 15   Adult           SVMSMOTE         1.0           0.836884
# 16   Adult             ADASYN         0.4           0.813957
# 17   Adult             ADASYN         0.6           0.830082
# 18   Adult             ADASYN         0.8           0.831597
# 19   Adult             ADASYN         1.0           0.831316
# 20   Adult    BorderlineSMOTE         0.4           0.816708
# 21   Adult    BorderlineSMOTE         0.6           0.831250
# 22   Adult    BorderlineSMOTE         0.8           0.831643
# 23   Adult    BorderlineSMOTE         1.0           0.830969
# 24   Adult         synthsonic         0.4           0.801867
# 25   Adult         synthsonic         0.6           0.799504
# 26   Adult         synthsonic         0.8           0.800419
# 27   Adult         synthsonic         1.0           0.801523
# 28   Adult  polynom_fit_SMOTE         0.4           0.800727
# 29   Adult  polynom_fit_SMOTE         0.6           0.800727
# 30   Adult  polynom_fit_SMOTE         0.8           0.801809
# 31   Adult  polynom_fit_SMOTE         1.0           0.801809
# 32   Adult       Random_SMOTE         0.4           0.807483
# 33   Adult       Random_SMOTE         0.6           0.812113
# 34   Adult       Random_SMOTE         0.8           0.810713
# 35   Adult       Random_SMOTE         1.0           0.814482
# 36   Adult            NoSMOTE         0.4           0.801437
# 37   Adult            NoSMOTE         0.6           0.801437
# 22  1.077019     0.006120
# 23  1.116764     0.014434
# 24  5.532363     0.251063
# 25  5.347658     0.064654
# 26  5.319701     0.179175
# 27  5.202759     0.049275
# 28  0.040220     0.001421
# 29  0.040199     0.002021
# 30  0.073512     0.005304
# 31  0.079298     0.001534
# 32  0.497506     0.020871
# 33  0.607188     0.012319
# 34  0.773293     0.018498
# 35  0.961211     0.012328
# 36  0.000982     0.000083
# 37  0.000973     0.000098
# 38  0.001041     0.000140
# 39  0.000957     0.000049

# %%
def get_best(df, dataset, metric) :
    "get best performance per oversampler for a specific dataset"
    
    temp_df = df[df['dataset'] == dataset]
    
    return df.loc[temp_df.groupby('oversampler')[metric].idxmax()].sort_values(metric, ascending=False)

def select_best(df, metric) :
    "get best performance per oversampler for all datasets"
    
    temp = []
    
    for dataset in df['dataset'].unique() :
        temp.append(get_best(df, dataset, metric))
        
    res = pd.concat(temp)
    
    return res

def ranking_oversampler(df, metric, return_all = False) :
    
    df2 = df.groupby('oversampler').mean().sort_values(metric, ascending=False)
    df3 = df2[['proportion', metric, f'{metric}_std']]
    
    if return_all :
        return df2
    else :
        return df3
    
def final_ranking(df, metric) :
    
    df2 = select_best(df, metric)
    
    return ranking_oversampler(df2,metric)

# %%
# make list of dataset types
cats = list(df_info[df_info['type'] == 'categorical']['dataset'])
nums = list(df_info[df_info['type'] == 'numerical']['dataset'])
mixed = list(df_info[df_info['type'] == 'mixed']['dataset'])

# %% [markdown]
# # categorical

# %%
dfc = df[df['dataset'].isin(cats)]
final_ranking(dfc, 'pr_auc')
# Out:
#                                                     proportion    pr_auc  \
# oversampler
# ('polynom_fit_SMOTE', "{'proportion': 1.0, 'top...    0.833333  0.834415
# NoOversampling                                        0.000000  0.829999
# ('Random_SMOTE', "{'proportion': 1.0, 'n_neighb...    0.466667  0.829338
# SVMSMOTE(n_jobs=-1, random_state=5, sampling_st...    0.633333  0.827487
# RandomOverSampler(random_state=5, sampling_stra...    0.400000  0.826162
# SMOTE(n_jobs=-1, random_state=5, sampling_strat...    0.600000  0.826036
# ADASYN(n_jobs=-1, random_state=5, sampling_stra...    0.433333  0.825550
# BorderlineSMOTE(n_jobs=-1, random_state=5, samp...    0.533333  0.824528
# ('synthsonic', "{'proportion': 1.0, 'distinct_t...    0.433333  0.821132
#
#                                                     pr_auc_std
# oversampler
# ('polynom_fit_SMOTE', "{'proportion': 1.0, 'top...    0.014458
# NoOversampling                                        0.011570
# ('Random_SMOTE', "{'proportion': 1.0, 'n_neighb...    0.014724
# SVMSMOTE(n_jobs=-1, random_state=5, sampling_st...    0.014201
# RandomOverSampler(random_state=5, sampling_stra...    0.012390
# SMOTE(n_jobs=-1, random_state=5, sampling_strat...    0.016542
# ADASYN(n_jobs=-1, random_state=5, sampling_stra...    0.017131
# BorderlineSMOTE(n_jobs=-1, random_state=5, samp...    0.014778
# ('synthsonic', "{'proportion': 1.0, 'distinct_t...    0.015160

# %% [markdown]
# # mixed

# %%
dfm = df[df['dataset'].isin(mixed)]
final_ranking(dfm, 'pr_auc')
# Out:
#                                                     proportion    pr_auc  \
# oversampler
# ADASYN(n_jobs=-1, random_state=5, sampling_stra...    0.581818  0.578692
# ('synthsonic', "{'proportion': 1.0, 'distinct_t...    0.636364  0.574120
# SMOTE(n_jobs=-1, random_state=5, sampling_strat...    0.436364  0.573334
# ('polynom_fit_SMOTE', "{'proportion': 1.0, 'top...    0.472727  0.572027
# ('Random_SMOTE', "{'proportion': 1.0, 'n_neighb...    0.600000  0.570462
# SVMSMOTE(n_jobs=-1, random_state=5, sampling_st...    0.454545  0.567902
# RandomOverSampler(random_state=5, sampling_stra...    0.600000  0.567079
# NoOversampling                                        0.000000  0.561700
# BorderlineSMOTE(n_jobs=-1, random_state=5, samp...    0.309091  0.559454
#
#                                                     pr_auc_std
# oversampler
# ADASYN(n_jobs=-1, random_state=5, sampling_stra...    0.065000
# ('synthsonic', "{'proportion': 1.0, 'distinct_t...    0.056930
# SMOTE(n_jobs=-1, random_state=5, sampling_strat...    0.060993
# ('polynom_fit_SMOTE', "{'proportion': 1.0, 'top...    0.061363
# ('Random_SMOTE', "{'proportion': 1.0, 'n_neighb...    0.056368
# SVMSMOTE(n_jobs=-1, random_state=5, sampling_st...    0.063671
# RandomOverSampler(random_state=5, sampling_stra...    0.051507
# NoOversampling                                        0.069286
# BorderlineSMOTE(n_jobs=-1, random_state=5, samp...    0.066364

# %% [markdown]
# # numerical

# %%
dfn = df[df['dataset'].isin(nums)]
final_ranking(dfn, 'pr_auc')
# Out:
#                                                     proportion    pr_auc  \
# oversampler
# SVMSMOTE(n_jobs=-1, random_state=5, sampling_st...        0.52  0.632250
# RandomOverSampler(random_state=5, sampling_stra...        0.54  0.631779
# ('synthsonic', "{'proportion': 1.0, 'distinct_t...        0.70  0.629249
# BorderlineSMOTE(n_jobs=-1, random_state=5, samp...        0.50  0.625611
# ADASYN(n_jobs=-1, random_state=5, sampling_stra...        0.36  0.621052
# SMOTE(n_jobs=-1, random_state=5, sampling_strat...        0.38  0.620947
# ('Random_SMOTE', "{'proportion': 1.0, 'n_neighb...        0.52  0.618087
# ('polynom_fit_SMOTE', "{'proportion': 1.0, 'top...        0.50  0.617412
# NoOversampling                                            0.00  0.617302
#
#                                                     pr_auc_std
# oversampler
# SVMSMOTE(n_jobs=-1, random_state=5, sampling_st...    0.053205
# RandomOverSampler(random_state=5, sampling_stra...    0.054252
# ('synthsonic', "{'proportion': 1.0, 'distinct_t...    0.050908
# BorderlineSMOTE(n_jobs=-1, random_state=5, samp...    0.061506
# ADASYN(n_jobs=-1, random_state=5, sampling_stra...    0.051550
# SMOTE(n_jobs=-1, random_state=5, sampling_strat...    0.056602
# ('Random_SMOTE', "{'proportion': 1.0, 'n_neighb...    0.053675
# ('polynom_fit_SMOTE', "{'proportion': 1.0, 'top...    0.043489
# NoOversampling                                        0.051237
