# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
input_path = "/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/CSV_results/Experiment3/"

# %%
base = pd.read_csv("base_case_kneighbors.csv")

# %%
dfs = []
for file in os.listdir(input_path) :
    dfs.append(pd.read_csv(input_path+file))
    
total = pd.concat(dfs, ignore_index=True)

# %%
def get_best(df, dataset, metric) :
    
    temp_df = df[df['dataset'] == dataset]
    
    return df.loc[temp_df.groupby('oversampler')[metric].idxmax()].sort_values(metric, ascending=False)

# %%
temp = []
for dataset in total['dataset'].unique() :
    temp.append(get_best(total,dataset,'avg_precision (AUPRC)'))
    
best_performers = pd.concat(temp)
best_performers = pd.concat([best_performers,base])

# %%
best_performers
# Out:
#          dataset        oversampler  proportion   runtime  \
# 21         ecoli  Borderline_SMOTE1         0.1  0.002750
# 28         ecoli  polynom_fit_SMOTE         0.1  0.000434
# 3          ecoli              SMOTE         0.1  0.002489
# 7          ecoli         synthsonic         0.1  1.979540
# 48         ecoli           SVMSMOTE         0.5  0.005569
# ..           ...                ...         ...       ...
# 22       webpage     NoOversampling         NaN       NaN
# 23   ozone_level     NoOversampling         NaN       NaN
# 24   mammography     NoOversampling         NaN       NaN
# 25  protein_homo     NoOversampling         NaN       NaN
# 26    abalone_19     NoOversampling         NaN       NaN
#
#                 classifier  balanced_accuracy  geometric_mean  f1_score  \
# 21  KNeighborsClassifier()           0.974747        0.974420  0.827586
# 28  KNeighborsClassifier()           0.938131        0.937886  0.814815
# 3   KNeighborsClassifier()           0.896465        0.894239  0.769231
# 7   KNeighborsClassifier()           0.922980        0.922958  0.733333
# 48  KNeighborsClassifier()           0.949495        0.948151  0.705882
# ..                     ...                ...             ...       ...
# 22  KNeighborsClassifier()           0.747919        0.704542  0.647887
# 23  KNeighborsClassifier()           0.499385        0.000000  0.000000
# 24  KNeighborsClassifier()           0.725635        0.672668  0.586466
# 25  KNeighborsClassifier()           0.698556        0.630209  0.564784
# 26  KNeighborsClassifier()           0.500000        0.000000  0.000000
#
#     precision    recall  avg_precision (AUPRC)
# 21   0.705882  1.000000               0.705882
# 28   0.733333  0.916667               0.681231
# 3    0.714286  0.833333               0.613256
# 7    0.611111  0.916667               0.569194
# 48   0.545455  1.000000               0.545455
# ..        ...       ...                    ...
# 22   0.930636  0.496914               0.476647
# 23   0.000000  0.000000               0.028674
# 24   0.829787  0.453488               0.389033
# 25   0.977011  0.397196               0.393429
# 26   0.000000  0.000000               0.007977
#
# [246 rows x 11 columns]

# %%
def rank_metric(df, metric) :
    
    res = best_performers.groupby('oversampler')[metric].mean().sort_values(ascending=False)
    return pd.DataFrame(res)

# %%
# avg precision score and balanced accuracy
rank_metric(best_performers, 'avg_precision (AUPRC)'), rank_metric(best_performers, 'balanced_accuracy')
# Out:
# (                   avg_precision (AUPRC)
#  oversampler
#  synthsonic                      0.387770
#  polynom_fit_SMOTE               0.373494
#  SMOTE                           0.365479
#  Random_SMOTE                    0.359755
#  RandomOverSampler               0.359754
#  Borderline_SMOTE1               0.359389
#  SVMSMOTE                        0.355037
#  ADASYN                          0.352445
#  NoOversampling                  0.342010
#  SMOTENC                         0.256340,
#                     balanced_accuracy
#  oversampler
#  SMOTE                       0.793465
#  ADASYN                      0.793092
#  Random_SMOTE                0.789480
#  polynom_fit_SMOTE           0.781200
#  synthsonic                  0.769459
#  Borderline_SMOTE1           0.766596
#  SVMSMOTE                    0.763431
#  RandomOverSampler           0.745537
#  SMOTENC                     0.737179
#  NoOversampling              0.675334)

# %%
from sklearn.metrics import precision_recall_curve

# %%
def find_range(df,group,value) :

    return best_performers.groupby(group)[value].agg(np.ptp).sort_values(ascending=False)

# %%
find_range(best_performers,'dataset','balanced_accuracy')
# Out:
# dataset
# libras_move       0.365991
# car_eval_4        0.324242
# oil               0.287886
# yeast_me2         0.249720
# abalone_19        0.205708
# arrhythmia        0.200704
# abalone           0.194242
# solar_flare_m0    0.190347
# us_crime          0.173727
# thyroid_sick      0.168571
# scene             0.167677
# car_eval_34       0.165689
# sick_euthyroid    0.164959
# wine_quality      0.156599
# ecoli             0.119949
# ozone_level       0.115467
# mammography       0.113633
# protein_homo      0.102129
# spectrometer      0.096894
# coil_2000         0.091808
# yeast_ml8         0.064437
# satimage          0.052789
# isolet            0.043771
# optical_digits    0.020961
# letter_img        0.011374
# pen_digits        0.002199
# webpage           0.000000
# Name: balanced_accuracy, dtype: float64

# %%
# top 5 biggest variation between oversamplers
biggest_change = find_range(best_performers,'dataset','balanced_accuracy')[:5]
biggest_change = list(biggest_change.index)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import auc
from imblearn.datasets import fetch_datasets
from pathlib import Path
import os
import sys
from sklearn.preprocessing import StandardScaler, LabelEncoder


def read_from_file(input_path, dataset, oversampler) :

    datasets = []

    target = os.path.join(input_path,dataset,oversampler)

    try :
        for file in os.listdir(target) :
            input_file = os.path.join(target, file)
            p = Path(input_file)

            temp_df = pd.read_csv(input_file)
            datasets.append(temp_df)
    
    except FileNotFoundError :
        print(f"No files found for {dataset} and {oversampler}")
        
    
    return datasets

def load_data(name) :
    
    dataset =  fetch_datasets()[name]
    X,y,title = dataset['data'], dataset['target'], dataset['DESCR']
    
    return X,y,title

def train_clf(dataset, sample, clf) :
    
    # load dataset to get test data
    X,y,title = load_data(dataset)
    
    _, X_test, _, y_test = train_test_split(X,y,test_size=0.35, stratify=y, random_state=5)
    
    data = sample.loc[:,:'target']
    
    X_train, y_train = data.iloc[:,:-1].values, data.iloc[:,-1].values
    
    y_train = LabelEncoder().fit_transform(y_train)
    
    
    clf.fit(X_train, y_train)

    probas = clf.predict_proba(X_test)[:,1]
    
    precision, recall, _ = precision_recall_curve(y_test, probas)
    aucscore = auc(recall, precision)
    
    return precision, recall, aucscore
    
def load_samples(df, dataset, location) :
    
    sampled_data = []
    
    sample = df[df['dataset'] == dataset].iloc[:,:3]
    
    for i in range(sample.shape[0]) :
        dataset_ = str(sample.iloc[i][0])
        oversampler_ = str(sample.iloc[i][1])
        prop_ = sample.iloc[i][2]
        if prop_ == 1.0 :
            prop = str(sample.iloc[i][2].astype(int))
        else :
            prop = str(sample.iloc[i][2])
            
        
        file = str(dataset_)+"_"+str(oversampler_)+"_"+str(prop).replace(".","_")
        path = loc / dataset_ / oversampler_ / file
        sampled_data.append(pd.read_csv(os.path.join(path.with_suffix('.csv'))))
        
    
    sampled_data = pd.concat(sampled_data)
    
    
    return sampled_data

def base_case(dataset, clf) :
    
    X,y,title = load_data(dataset)
    
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.35, stratify=y, random_state=5)
    
    clf.fit(X_train,y_train)
    
    probas = clf.predict_proba(X_test)[:,1]
    
    precision, recall, _ = precision_recall_curve(y_test, probas)
    #aucscore = auc(recall, precision)
    
    return precision, recall, aucscore

def plot_pr_curve(dataset,sampler, pr,rec) :
    
    plt.figure()
    plt.plot(rec, pr, marker='.', label=sampler)

    plt.title(f"PR curve {dataset}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

    plt.show()

# %%
biggest_change
# Out:
# ['libras_move', 'car_eval_4', 'abalone_19', 'arrhythmia', 'abalone']

# %% [markdown]
# # libras move

# %%
from sklearn.neighbors import KNeighborsClassifier

# analysis of xgboost - libras_move
loc = Path('/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/Samples2/')
samples = load_samples(best_performers, 'libras_move', loc)

d = 'libras_move'
clf = KNeighborsClassifier()


samplers = samples['oversampler'].unique()

plt.figure(figsize=(12,7))
for s in samplers :
    
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

plt.show()

# %% [markdown]
# # car eval 4

# %%
import xgboost as xgb

# analysis of xgboost - libras_move
loc = Path('/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/Samples2/')

d = 'car_eval_4'
samples = load_samples(best_performers, d, loc)
clf = KNeighborsClassifier()


samplers = samples['oversampler'].unique()

plt.figure(figsize=(12,7))
for s in samplers :
    
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

plt.show()

# %%
pr,rec, auc = base_case('car_eval_4', clf)
plot_pr_curve('car_eval_4', 'NoOversampling', pr, rec)

# %%
for s in samplers :
    plt.figure()
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

    plt.show()

# %% [markdown]
# # abalone

# %%
import xgboost as xgb

# analysis of xgboost - libras_move
loc = Path('/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/Samples2/')

d = 'abalone'
samples = load_samples(best_performers, d, loc)
clf = KNeighborsClassifier()


samplers = samples['oversampler'].unique()

plt.figure(figsize=(12,7))
for s in samplers :
    
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

plt.show()

# %%
pr,rec, auc = base_case('abalone', clf)
plot_pr_curve('abalone', 'NoOversampling', pr, rec)

# %%
for s in samplers :
    plt.figure()
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

    plt.show()

# %% [markdown]
# # arrhythmia

# %%
import xgboost as xgb

# analysis of xgboost - libras_move
loc = Path('/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/Samples2/')

d = 'arrhythmia'
samples = load_samples(best_performers, d, loc)
clf = KNeighborsClassifier()


samplers = samples['oversampler'].unique()

plt.figure(figsize=(12,7))
for s in samplers :
    
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

plt.show()

# %%
pr,rec, auc = base_case('arrhythmia', clf)
plot_pr_curve('arrhythmia', 'NoOversampling', pr, rec)

# %%
for s in samplers :
    plt.figure()
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

    plt.show()

# %% [markdown]
# # abalone_19

# %%
import xgboost as xgb

# analysis of xgboost - libras_move
loc = Path('/Users/tristenmarto/Documents/Studie/Thesis/Synthsonic_data_analysis/Samples2/')

d = 'abalone_19'
samples = load_samples(best_performers, d, loc)
clf = KNeighborsClassifier()


samplers = samples['oversampler'].unique()

plt.figure(figsize=(12,7))
for s in samplers :
    
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

plt.show()

# %%
pr,rec, auc = base_case('abalone_19', clf)
plot_pr_curve('abalone_19', 'NoOversampling', pr, rec)

# %%
for s in samplers :
    plt.figure()
    sample = samples[samples['oversampler'] == s]
    
    pr, rec, aucscore = train_clf(d,sample,clf)

    plt.plot(rec, pr, marker='.', label=s)

    plt.title(f"PR curve {d}")
    plt.xlabel('Recall')
    plt.ylabel('Precision')

    plt.legend()

    plt.show()
