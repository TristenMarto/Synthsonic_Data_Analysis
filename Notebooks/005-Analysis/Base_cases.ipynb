# %%
import pandas as pd
import numpy as np

import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import auc
from imblearn.datasets import fetch_datasets
from pathlib import Path
import os
import sys
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from imblearn.metrics import geometric_mean_score, classification_report_imbalanced

from sklearn.model_selection import cross_validate, train_test_split
from sklearn.metrics import (recall_score, roc_auc_score, confusion_matrix, precision_score, precision_recall_curve,
                             f1_score, balanced_accuracy_score, accuracy_score, average_precision_score)

# %%
def load_data(name) :
    
    dataset =  fetch_datasets()[name]
    X,y,title = dataset['data'], dataset['target'], dataset['DESCR']
    y_enc = LabelEncoder().fit_transform(y)
        
    return X,y_enc,title

def test_metrics(dataset, clf, random_state=5) :

    # get back the train test split
    X,y, title = load_data(dataset)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, stratify = y, random_state = random_state)
    
    res_df = pd.DataFrame({
        "dataset":title, 
        "oversampler" : "NoOversampling"
        }, index=[0])

    res_df['classifier'] = clf

    clf.fit(X_train, y_train)
    prediction = clf.predict(X_test)
    probas = clf.predict_proba(X_test)

    # get metrics
    res_df['balanced_accuracy'] = balanced_accuracy_score(y_test,prediction)
    res_df['geometric_mean'] = geometric_mean_score(y_test, prediction)
    res_df['f1_score'] = f1_score(y_test, prediction)
    res_df['precision'] = precision_score(y_test,prediction)
    res_df['recall'] = recall_score(y_test,prediction)
    res_df['avg_precision (AUPRC)'] = average_precision_score(y_test, prediction)

    return res_df


def base_case(dataset, clf) :
    
    X,y,title = load_data(dataset)
    
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.35, stratify=y, random_state=5)
    
    clf.fit(X_train,y_train)
    
    probas = clf.predict_proba(X_test)[:,1]
    
    precision, recall, _ = precision_recall_curve(y_test, probas)
    #aucscore = auc(recall, precision)
    
    return precision, recall, aucscore

# %%
datasets = list(fetch_datasets().keys())
clf = xgb.XGBClassifier(verbosity=0, random_state = 0, use_label_encoder=False)
dfs = []
for dataset in datasets :
    print(dataset)
    dfs.append(test_metrics(dataset, clf))
    
df = pd.concat(dfs)
# Out:
# ecoli
# optical_digits
# satimage
# pen_digits
# abalone
# sick_euthyroid
# spectrometer
# car_eval_34
# isolet
# us_crime
# yeast_ml8
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# scene
# libras_move
# thyroid_sick
# coil_2000
# arrhythmia
# solar_flare_m0
# oil
# car_eval_4
# wine_quality
# letter_img
# yeast_me2
# webpage
# ozone_level
# mammography
# protein_homo
# abalone_19
# /Users/tristenmarto/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df.to_csv("base_case_xgb.csv", index=False)

# %%
df
# Out:
#           dataset     oversampler  \
# 0           ecoli  NoOversampling
# 0  optical_digits  NoOversampling
# 0        satimage  NoOversampling
# 0      pen_digits  NoOversampling
# 0         abalone  NoOversampling
# 0  sick_euthyroid  NoOversampling
# 0    spectrometer  NoOversampling
# 0     car_eval_34  NoOversampling
# 0          isolet  NoOversampling
# 0        us_crime  NoOversampling
# 0       yeast_ml8  NoOversampling
# 0           scene  NoOversampling
# 0     libras_move  NoOversampling
# 0    thyroid_sick  NoOversampling
# 0       coil_2000  NoOversampling
# 0      arrhythmia  NoOversampling
# 0  solar_flare_m0  NoOversampling
# 0             oil  NoOversampling
# 0      car_eval_4  NoOversampling
# 0    wine_quality  NoOversampling
# 0      letter_img  NoOversampling
# 0       yeast_me2  NoOversampling
# 0         webpage  NoOversampling
# 0     ozone_level  NoOversampling
# 0     mammography  NoOversampling
# 0    protein_homo  NoOversampling
# 0      abalone_19  NoOversampling
#
#                                           classifier  balanced_accuracy  \
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.786616
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.960852
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.822050
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.986917
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.539616
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.922958
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.896894
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.971580
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.878788
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.719327
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.500000
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.540390
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.682995
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.939079
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.536990
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.989437
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.563605
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.673504
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.952381
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.622110
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.966785
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.672242
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.826174
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.599862
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.777683
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.880673
# 0  XGBClassifier(base_score=0.5, booster='gbtree'...           0.500000
#
#    geometric_mean  f1_score  precision    recall  avg_precision (AUPRC)
# 0        0.759895  0.700000   0.875000  0.583333               0.555462
# 0        0.960125  0.952113   0.982558  0.923497               0.914937
# 0        0.806286  0.724868   0.801170  0.661836               0.563199
# 0        0.986834  0.985465   0.997059  0.974138               0.973754
# 0        0.344201  0.159204   0.222222  0.124031               0.109506
# 0        0.921198  0.840000   0.815534  0.865979               0.718688
# 0        0.891645  0.857143   0.923077  0.800000               0.755507
# 0        0.971431  0.913043   0.875000  0.954545               0.838730
# 0        0.871077  0.836565   0.926380  0.762626               0.724742
# 0        0.670955  0.534884   0.638889  0.460000               0.334860
# 0        0.000000  0.000000   0.000000  0.000000               0.073935
# 0        0.292812  0.149254   0.555556  0.086207               0.114559
# 0        0.609608  0.500000   0.750000  0.375000               0.323267
# 0        0.937317  0.911565   0.943662  0.881579               0.839141
# 0        0.294687  0.134387   0.283333  0.088083               0.079244
# 0        0.989380  0.842105   0.727273  1.000000               0.727273
# 0        0.367581  0.206897   0.428571  0.136364               0.099836
# 0        0.594578  0.454545   0.625000  0.357143               0.252247
# 0        0.951190  0.950000   1.000000  0.904762               0.908265
# 0        0.498553  0.357143   0.625000  0.250000               0.184079
# 0        0.966225  0.961702   0.991228  0.933884               0.928117
# 0        0.591571  0.444444   0.600000  0.352941               0.234214
# 0        0.808103  0.759857   0.905983  0.654321               0.602561
# 0        0.454466  0.277778   0.416667  0.208333               0.109506
# 0        0.746050  0.666667   0.827586  0.558140               0.472204
# 0        0.872598  0.846753   0.953216  0.761682               0.728169
# 0        0.000000  0.000000   0.000000  0.000000               0.007977
